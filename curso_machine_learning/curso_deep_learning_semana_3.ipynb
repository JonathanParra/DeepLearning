# %% [markdown]
# # Clasificación

# %% [markdown]
#  Resulta que la regresión lineal no es un buen algoritmo para los problemas de clasificación. Veamos por qué y esto nos llevará a un algoritmo diferente llamado regresión logística.

# %% [markdown]
# ### Regresión logística.

# %% [markdown]
# Cuál es uno de los algoritmos de aprendizaje más populares y utilizados en la actualidad. Estos son algunos ejemplos de problemas de clasificación:
#
# ![size vs price](images/regresion_logistica_01.png)

# %% [markdown]
# Este tipo de problema de clasificación en el que solo hay dos salidas posibles se denomina **clasificación binaria** Donde la palabra binario se refiere a que solo hay dos clases o dos categorías posibles.

# %% [markdown]
# Por lo general, utilizo los números cero y uno para representar la respuesta y, porque eso encajará más fácilmente con los tipos de algoritmos de aprendizaje que queremos implementar. Pero cuando hablamos de ello, a menudo decimos que no o que sí, o que también es falso o verdadero. Una de las tecnologías más utilizadas es la de denominar a la clase falsa o cero.

# %% [markdown]
# ![size vs price](images/regresion_logistica_01.png)

# %% [markdown]
# ## Regresión Logística

# %% [markdown]
# vio que la regresión lineal no es un buen algoritmo para este problema. Por el contrario, lo que hacemos con la regresión logística es ajustar una curva parecida a esta curva en forma de S a este conjunto de datos. En este ejemplo, si un paciente llega con un tumor de este tamaño, que estoy mostrando en el eje x, el algoritmo arrojará un resultado de 0.7, lo que sugiere que está más cerca o tiene más probabilidades de ser maligno y benigno.

# %% [markdown]
# ![size vs price](images/regresion_logistica_02.png)

# %% [markdown]
# En el primer paso, espero que recuerdes que una función de línea recta, como una función de regresión lineal, se puede definir como un producto de x más b. Almacenemos este valor en una variable a la que llamaré z, y resultará ser la misma z que la que viste en la diapositiva anterior, pero lo veremos en un minuto.

# %% [markdown]
# ![size vs price](images/regresion_logistica_04.png)

# %% [markdown]
# El siguiente paso es tomar este valor de z y pasarlo a la función sigmoidea, también llamada función logística, g. Ahora, g de z produce un valor calculado con esta fórmula, 1 sobre 1 más e elevado a z negativo. Va a haber entre 0 y 1. Cuando tomas estas dos ecuaciones y las juntas, obtienes el modelo de regresión logística f de x, que es igual a g de wx más b. O equivalentemente g de z, que es igual a esta fórmula de aquí. Este es el modelo de regresión logística, y lo que hace es introducir una entidad o conjunto de entidades X y generar un número entre 0 y 1. A continuación, veamos cómo interpretar el resultado de la regresión logística.

# %% [markdown]
# Volveremos al ejemplo de clasificación de tumores. La forma en que les animo a pensar en el resultado de las regresiones logísticas es pensar en ello como la probabilidad de que la clase o la etiqueta y sea igual a 1 dada una determinada entrada x. Por ejemplo, en esta aplicación, donde x es el tamaño del tumor e y es 0 o 1, si entra una paciente y tiene un tumor de un tamaño determinado x, y si se basa en esta entrada x, el modelo yo añadiré 0.7 entonces lo que eso significa es que el modelo está prediciendo o el modelo cree que hay un 70 por ciento de probabilidades de que la verdadera etiqueta y sea igual a 1 para este paciente. En otras palabras, el modelo nos dice que cree que el paciente tiene un 70 por ciento de probabilidades de que el tumor se convierta en maligno.

# %% [markdown]
# ![size vs price](images/regresion_logistica_05.png)

# %% [markdown]
# Así que y tiene que ser 0 o 1 y, por lo tanto, la probabilidad de que sea 0 o 1 estos dos números tienen que sumar uno o una probabilidad del 100 por ciento. Por eso, si la probabilidad de que y sea 1 es del 0,7 o del 70 por ciento, entonces la probabilidad de que sea 0 tiene que ser del 0,3 o el 30 por ciento. Si algún día lees artículos de investigación o reseñas de blogs sobre todas las regresiones logísticas, a veces verás esta notación según la cual f de x es igual a p de y es igual a 1 dadas las entidades de entrada x y con los parámetros w y b. Lo que se usa aquí con el punto y coma es que w y b son parámetros que afectan al cálculo de cuál es la probabilidad de que y sea igual a 1 dada la entidad de entrada x. Para el propósito de esta clase, no te preocupes demasiado por el significado de esta línea vertical y el punto y coma.

# %% [markdown]
# ![size vs price](images/regresion_logistica_06.png)

# %% [markdown]
# Laboratorio: C1_W3_Lab02_Sigmoid_function_Soln.ipynb

# %% [markdown]
# ## Limite de desicion (Decision Boundary)
#
#  Ahora, echemos un vistazo al límite de decisión para tener una mejor idea de cómo la regresión logística calcula estas predicciones.
# En resumen, aquí se explica cómo se calculan los resultados de los modelos de regresión logística en dos pasos.
#
# 1.-En el primer paso, calculamos z como w.x más b. A continuación, aplicamos la función sigmoidea g a este valor z.
#
# ![size vs price](images/regresion_logistica_07.png)
#
# También aquí tenemos la fórmula de la función sigmoidea.
#
# ![size vs price](images/regresion_logistica_08.png)
#
# Otra forma de escribir esto es decir que f de x es igual a g, la función sigmoidea, también llamada función logística, aplicada a w.x más b, donde este es, por supuesto, el valor de z.
# ![size vs price](images/regresion_logistica_10.png)

# %% [markdown]
# Si tomas la definición de la función sigmoidea y agregas la definición de z, entonces encontrarás que f de x es igual a esta fórmula de aquí, 1 sobre 1 más e al negativo z, donde z es wx más b.

# %% [markdown]
#  Tal vez recuerdes con anterioridad que interpretamos esto como la probabilidad de que y sea igual a 1 dada x y con parámetros w y b.
#
#  ![size vs price](images/regresion_logistica_11.png)
#
#  Será un número como 0.7 o 0.3. Ahora, ¿qué pasa si quieres aprender el algoritmo para predecir? ¿El valor de y va a ser cero o uno? Bueno, una cosa que puedes hacer es establecer un umbral por encima del cual puedas predecir que y es uno, o establecer que la predicción sea igual a uno y por debajo del cual puedes decir que mi predicción va a ser igual a cero. Una opción común sería elegir un umbral de 0.5 para que si f de x es mayor o igual a 0.5, entonces predecir y sea uno.
#
#   ![size vs price](images/regresion_logistica_12.png)
#
#   Escribimos esa predicción como y que es igual a 1, o si f de x es menor que 0,5, entonces predecimos y es 0
#
#    ![size vs price](images/regresion_logistica_13.png)

# %% [markdown]
# En otras palabras, cuando f de x es mayor o igual a 0.5. Recordaremos que f de x es igual a g de z. Por lo tanto, f es mayor o igual a 0.5 siempre que g de z sea mayor o igual a 0.5. Pero, ¿cuándo es g de z mayor o igual a 0.5? Bueno, aquí hay una función sigmoidea.

# %% [markdown]
# Así que g de z es mayor o igual a 0.5 siempre que z sea mayor o igual a 0. Es decir, siempre que z esté en la mitad derecha de este eje. Finalmente, ¿cuándo z es mayor o igual a cero? Bueno, z es igual a w.x más b, así que z es mayor o igual a cero siempre que w.x más b sea mayor o igual a cero. En resumen, lo que ha visto aquí es que el modelo predice 1 siempre que w.x más b sea mayor o igual a 0. Por el contrario, cuando w.x más b es menor que cero, el algoritmo predice que y es 0.
#
#  ![size vs price](images/regresion_logistica_14.png)

# %% [markdown]
# Voy a tomar un ejemplo de un problema de clasificación en el que hay dos entidades, x1 y x2, en lugar de una sola entidad. He aquí un conjunto de entrenamiento en el que las pequeñas cruces rojas indican los ejemplos positivos y los pequeños círculos azules indican los negativos. Las cruces rojas corresponden a y es igual a 1, y los círculos azules corresponden a y es igual a 0.
#
#  ![size vs price](images/regresion_logistica_15.png)

# %% [markdown]
# El modelo de regresión logística hará predicciones usando esta función f de x igual a g de z, donde z es ahora esta expresión, w1x1 más w2x2 más b, porque tenemos dos características x1 y x2. Supongamos, para este ejemplo, que el valor de los parámetros es w1 igual a 1, w2 es igual a 1 y b es igual a menos 3. Veamos ahora cómo la regresión logística hace predicciones. En particular, averigüemos cuándo wx más b es mayor que igual a 0 y cuándo wx más b es menor que 0.
#
#  ![size vs price](images/regresion_logistica_16.png)

# %% [markdown]
# Para averiguarlo, hay una línea muy interesante que observar, que es cuando wx más b es exactamente igual a 0. Resulta que esta línea también se llama límite de decisión porque es la línea en la que eres casi neutral en cuanto a si y es 0 o y es 1. Ahora, para los valores de los parámetros w_1, w_2 y b que habíamos anotado anteriormente, este límite de decisión es simplemente x_1 más x_2 menos 3. ¿Cuándo x_1 más x_2 menos 3 es igual a 0? Bueno, eso corresponderá a la línea x_1 más x_2 igual a 3, y esa es la línea que se muestra aquí. Esta línea resulta ser el límite de decisión, donde si las entidades x están a la derecha de esta línea, la regresión logística predeciría 1 y, a la izquierda de esta línea, la regresión logística con predice 0. En otras palabras, lo que acabamos de visualizar es el límite de decisión para la regresión logística cuando los parámetros w_1, w_2 y b son 1,1 y menos 3.
#
#  ![size vs price](images/regresion_logistica_18.png)

# %% [markdown]
# Veamos ahora un ejemplo más complejo en el que el límite de decisión ya no es una línea recta. Como antes, las cruces indican que la clase y es igual a 1, y los círculos pequeños indican que la clase y es igual a 0.
#
# ![size vs price](images/regresion_logistica_19.png)

# %% [markdown]
#  A principios de la semana pasada, vio cómo usar polinomios en la regresión lineal, y puede hacer lo mismo en la regresión logística. Esto establece que z sea w_1, x_1 al cuadrado más w_2, x_2 al cuadrado más b. Con esta selección de entidades, las entidades polinomiales forman una regresión logística. La F de x, que es igual a g de z, ahora es la g de esta expresión de aquí.
#
# ![size vs price](images/regresion_logistica_20.png)
#
#  Digamos que acabamos eligiendo w_1 y w_2 como 1 y b como menos 1. Z es igual a 1 por x_1 al cuadrado más 1 por x_2 al cuadrado menos 1. El límite de decisión, como antes, corresponderá a cuando z sea igual a 0. Esta expresión será igual a 0 cuando x_1 al cuadrado más x_2 al cuadrado sea igual a 1. Si graficas en el diagrama de la izquierda, la curva correspondiente a x_1 al cuadrado más x_2 al cuadrado es igual a 1, resulta ser el círculo. Cuando x_1 al cuadrado más x_2 al cuadrado es mayor o igual a 1, esa es el área situada fuera del círculo y es entonces cuando se predice que y será 1. Por el contrario, cuando x_1 al cuadrado más x_2 al cuadrado es menor que 1, esa es el área dentro del círculo y ahí es cuando se predice que y será 0.

# %% [markdown]
# ¿Podemos crear límites de decisión aún más complejos que estos? Sí, puedes. Puedes hacerlo si tienes términos polinomiales de orden aún mayor. Supongamos que z es w_1, x_1 más w_2, x_2 más w_3, x_1 al cuadrado más w_4, x_1, x_2 más w_5, x_2 al cuadrado. Entonces es posible obtener límites de decisión aún más complejos. El modelo puede definir los límites de decisión, como en este ejemplo, una elipse como esta o con una selección diferente de los parámetros. Incluso puede obtener límites de decisión más complejos, que pueden tener el aspecto de funciones que tal vez tengan ese aspecto.
#
# ![size vs price](images/regresion_logistica_22.png)
#
#
# Así que este es un ejemplo de un límite de decisión aún más complejo que los que hemos visto anteriormente. Esta implementación de la regresión logística predecirá que y es igual a 1 dentro de esta forma y fuera de la forma predecirá y es igual a 0.

# %% [markdown]
# Con estas características polinomiales, puede obtener límites de decisión muy complejos. En otras palabras, la regresión logística puede aprender a ajustar datos bastante complejos. Sin embargo, si no incluyera ninguno de estos polinomios de orden superior, si las únicas entidades que utiliza son x_1, x_2, x_3, etc., el límite de decisión para la regresión logística siempre será lineal, siempre será una línea recta. En el próximo laboratorio opcional, también podrás ver la implementación en código del límite de decisión.

# %% [markdown]
# ## Funcion de costo para Regresion Logistica

# %% [markdown]
# Recuerde que la función de costo le brinda una forma de medir qué tan bien un conjunto específico de parámetros se ajusta a los datos de entrenamiento.  De este modo, le brinda una forma de intentar elegir mejores parámetros.

# %% [markdown]
#  veremos cómo la función de coste del error cuadrático no es una función de coste ideal para la regresión logística.
#
#
#   Este es el aspecto que podría tener el conjunto de entrenamiento para nuestro modelo de regresión logística. Aquí cada fila podría corresponder a un paciente que estaba visitando al médico y otro tenía algún diagnóstico. Como antes, usaremos m para indicar el número de ejemplos de entrenamiento.
#
#   ![size vs price](images/regresion_logistica_23.png)

# %% [markdown]
# Cada ejemplo de entrenamiento tiene una o más características, como el tamaño del tumor, la edad del paciente, etc., para un total de n características. Llamemos a las entidades X_1 a X_n. Como se trata de una tarea de clasificación binaria, la etiqueta objetivo y solo toma dos valores, 0 o 1.

# %% [markdown]
# Por último, el modelo de regresión logística se define mediante esta ecuación.
#
#  ![size vs price](images/regresion_logistica_24.png)
#
#  La pregunta que desea responder es, dado este conjunto de entrenamiento, ¿cómo puede elegir los parámetros w y b? Recuerde que para la regresión lineal, esta es la función de costo del error cuadrático. Lo único que cambié es que puse la mitad dentro de la suma en lugar de fuera de la suma.
#
#  ![size vs price](images/regresion_logistica_25.png)

# %% [markdown]
# Tal vez recuerdes que en el caso de la regresión lineal, donde f de x es la función lineal, w punto x más b.
#
# ![size vs price](images/regresion_logistica_26.png)
#
# La función de coste tiene este aspecto, es una función convexa o una forma de cuenco o de martillo.
#
# ![size vs price](images/regresion_logistica_27.png)
#
#
#  El gradiente descendiente tendrá este aspecto, en el que se da un paso, un paso, etc. para converger en el mínimo global. Ahora puede intentar usar la misma función de costo para la regresión logística.
#
#  ![size vs price](images/regresion_logistica_28.png)

# %% [markdown]
# Pero resulta que si escribo f de x igual a 1 sobre 1 más e, a menos wx más b y grafico la función de costo usando este valor de f de x, entonces el costo se vería así. Esto se convierte en lo que se llama una función de costo no convexa, no es convexa. Lo que esto significa es que si intentaras usar el gradiente de descenso.
#
#  ![size vs price](images/regresion_logistica_29.png)
#
#
#  Hay muchos mínimos locales que puedes llegar a ser pésimos. Resulta que para la regresión logística, esta función de coste de error cuadrático no es una buena opción.
#
#   En cambio, habrá una función de costo diferente que puede hacer que la función de costo vuelva a ser convexa.
#
#   Se puede garantizar que el descenso del gradiente converja al mínimo global. Lo único que cambié es que puse la mitad dentro de la suma en lugar de fuera de la suma. Esto simplificará un poco los cálculos que verás más adelante en esta diapositiva. Para crear una nueva función de costo, una que usaremos para la regresión logística.

# %% [markdown]
# Voy a cambiar un poco la definición de la función de coste J de w y b. En concreto, si analizamos esta suma, llamemos a este término dentro de la pérdida en un solo ejemplo de entrenamiento.
#
#  ![size vs price](images/regresion_logistica_30.png)
#
# Voy a denotar la pérdida mediante esta L mayúscula y, en función de la predicción del algoritmo de aprendizaje, f de x, así como de la etiqueta verdadera y. La pérdida dada el predictor f de x y la verdadera etiqueta y es igual en este caso a 1,5 de la diferencia al cuadrado. Veremos en breve que, al elegir una forma diferente para esta función de pérdida, podremos mantener la función de costo general, que es 1 sobre n veces la suma de estas funciones de pérdida, en una función convexa.
#
#
# Ahora, la función de pérdida introduce f de x y la etiqueta verdadera y, y nos indica qué tan bien nos va con ese ejemplo. Voy a escribir aquí la definición de la función de pérdida que usaremos para la regresión logística.
#
# ![size vs price](images/regresion_logistica_31.png)
#
# Si la etiqueta y es igual a 1, entonces la pérdida es el logaritmo negativo de f de x y si la etiqueta y es igual a 0, entonces la pérdida es el logaritmo negativo de 1 menos f de x.

# %% [markdown]
#  Veamos por qué esta función de pérdida, ojalá tenga sentido. Consideremos primero el caso en el que y es igual a 1 y representemos gráficamente el aspecto de esta función para hacernos una idea de lo que hace esta función de pérdida. Recuerda que la función de pérdida mide tu rendimiento en un ejemplo de entrenamiento y consiste en sumar las pérdidas de todos los ejemplos de entrenamiento que obtengas, la función de coste, que mide tu rendimiento en todo el conjunto de entrenamiento. Si graficas el logaritmo de f, se ve como esta curva, donde f está en el eje horizontal. Una gráfica de un negativo del logaritmo de f se ve así, en la que simplemente volteamos la curva a lo largo del eje horizontal. Observa que se cruza con el eje horizontal cuando f es igual a 1 y continúa hacia abajo desde allí.
#
#  ![size vs price](images/regresion_logistica_32.png)

# %% [markdown]
# Ahora, f es el resultado de la regresión logística. Por lo tanto, f siempre está entre cero y uno porque el resultado de la regresión logística siempre está entre cero y uno. Por lo tanto, la única parte de la función que es relevante es esta parte de aquí, que corresponde a f entre 0 y 1. Acerquemos la imagen y veamos más de cerca esta parte del gráfico. Si el algoritmo predice una probabilidad cercana a 1 y la etiqueta verdadera es 1, entonces la pérdida es muy pequeña. Es prácticamente 0 porque estás muy cerca de la respuesta correcta. Ahora continúa con el ejemplo de que la etiqueta verdadera y es 1, supongamos que todo es un tumor maligno.
#
# ![size vs price](images/regresion_logistica_33.png)

# %% [markdown]
# Si el algoritmo predice 0.5, entonces la pérdida está en este punto, que es un poco más alta pero no tan alta. Por el contrario, si el algoritmo tuviera un resultado de 0,1 si pensara que solo hay un 10 por ciento de probabilidades de que el tumor sea maligno, y realmente es 1. Si realmente es maligno, entonces la pérdida es un valor mucho más alto que el de aquí. Cuando y es igual a 1, la función de pérdida incentiva o fomenta, o ayuda a que el algoritmo haga predicciones más precisas porque la pérdida es la más baja, cuando predice valores cercanos a 1
#
# ![size vs price](images/regresion_logistica_34.png)
#
# ![size vs price](images/regresion_logistica_35.png)

# %% [markdown]
# En esta Imagen, veamos la segunda parte de la función de pérdida correspondiente a cuando y es igual a 0. En este caso, la pérdida es el logaritmo negativo de 1 menos f de x.
#
# ![size vs price](images/regresion_logistica_36.png)
#
#
# Cuando se traza esta función, en realidad se ve así. El rango de f está limitado a 0 a 1 porque la regresión logística solo genera valores entre 0 y 1.
#
#
# ![size vs price](images/regresion_logistica_37.png)
#
#  En esta gráfica, que corresponde a y igual a 0, el eje vertical muestra el valor de la pérdida para diferentes valores de f de x. Cuando f es 0 o está muy cerca de 0, la pérdida también será muy pequeña, lo que significa que si la etiqueta verdadera es 0 y la predicción del modelo está muy cerca de 0, bueno, casi acertó, por lo que la pérdida está apropiadamente muy cerca de 0. Cuanto mayor sea el valor de f de x, mayor será la pérdida porque la predicción está más alejada de la verdadera etiqueta 0. De hecho, cuando esa predicción se acerca a 1, la pérdida en realidad se acerca al infinito.
#
# Volviendo al ejemplo de predicción de tumores, nos limitamos a decir que si el modelo predice que es casi seguro que el tumor del paciente sea maligno (por ejemplo, un 99,9 por ciento de probabilidades de desarrollar una neoplasia maligna), resulta que en realidad no es maligno, por lo que y es igual a 0, entonces penalizamos al modelo con una pérdida muy alta. En este caso de y es igual a 0, por lo que en el caso de y es igual a 1 en la diapositiva anterior, cuanto más se aleje la predicción f de x del valor real de y, mayor será la pérdida. De hecho, si f de x se acerca a 0, la pérdida aquí es realmente muy grande y, de hecho, se acerca al infinito. Cuando la etiqueta verdadera es 1, se incentiva fuertemente al algoritmo a no predecir algo demasiado cercano a 0.
#
# ![size vs price](images/regresion_logistica_38.png)
#
#  ha visto por qué la función de coste del error cuadrático no funciona bien en la regresión logística. También definimos la pérdida para un único ejemplo de entrenamiento y elaboramos una nueva definición de la función de pérdida para la regresión logística. Resulta que con esta opción de función de pérdida, la función de coste global será convexa y, por lo tanto, se puede utilizar de forma fiable el gradiente descendente para llegar al mínimo global.
#
#  ![size vs price](images/regresion_logistica_39.png)
#
#  Demostrar que esta función es convexa está fuera del alcance de este coste. Puede recordar que la función de coste es una función de todo el conjunto de entrenamiento y, por lo tanto, es el promedio o 1 sobre m multiplicado por la suma de la función de pérdida en los ejemplos de entrenamiento individuales. El coste de un determinado conjunto de parámetros, w y b, es igual a 1 sobre m multiplicado por la suma de todos los ejemplos de entrenamiento de la pérdida en los ejemplos de entrenamiento. Si puede encontrar el valor de los parámetros w y b minimizándolo, tendrá un conjunto de valores bastante bueno para los parámetros w y b para la regresión logística.

# %% [markdown]
# ## Función de costes simplificada para la regresión logística
#
#
#  verás una forma un poco más sencilla de escribir las funciones de pérdida y coste, de modo que la implementación puede resultar un poco más sencilla si utilizamos el gradiente descendente para ajustar los parámetros de un modelo de regresión logística
#
#  Como recordatorio, aquí está la función de pérdida que habíamos definido anteriormente para la regresión logística.
#
#   ![size vs price](images/regresion_logistica_40.png)
#
#  Como todavía estamos trabajando en un problema de clasificación binaria, y es cero o uno. Como y es cero o uno y no puede tomar ningún otro valor que no sea cero o uno, podremos encontrar una forma más sencilla de escribir esta función de pérdida
#
#   ![size vs price](images/regresion_logistica_41.png)
#
# Con una predicción f de x y la etiqueta objetivo y, la pérdida es igual a menos y multiplicado por el logaritmo de f menos 1 menos y multiplicado por el logaritmo de 1 menos f. Resulta que esta ecuación, que acabamos de escribir en una línea, es completamente equivalente a esta fórmula más compleja de aquí arriba. Veamos por qué es así. Recuerde que y solo puede tomar los valores de uno o cero. En el primer caso, digamos que y es igual a 1. La primera y de aquí es uno y este 1 menos y es 1 menos 1, que por lo tanto es igual a 0. Así que la pérdida se convierte en 1 multiplicado por el logaritmo de f de x menos 0 veces por un montón de cosas.
#
#
#  ![size vs price](images/regresion_logistica_42.png)
#
# Eso se convierte en cero y desaparece. Cuando y es igual a 1, la pérdida es de hecho el primer término de arriba, es decir, el logaritmo negativo de f de x.
#
#  Veamos el segundo caso, en el que y es igual a 0. En este caso, esta y aquí es igual a 0, por lo que el primer término desaparece y el segundo término es 1 menos 0 multiplicado por el término logarítmico. La pérdida se convierte en menos 1 multiplicado por el logaritmo de 1 menos f de x. Es igual al segundo término que aparece aquí arriba. En el caso de que y sea igual a 0, también obtenemos la función de pérdida original, tal como se definió anteriormente.
#
#  ![size vs price](images/regresion_logistica_43.png)
#
#
#
# Lo que ves es que tanto si y es uno como cero, esta única expresión de aquí equivale a la expresión más compleja de aquí arriba, por lo que esto nos da una forma más sencilla de escribir la pérdida con una sola ecuación sin separar estos dos casos, como hicimos en la parte superior. Usando esta función de pérdida simplificada, regresemos y escribamos la función de costo para la regresión logística

# %% [markdown]
#  De nuevo, aquí está la función de pérdida simplificada. Recuerde que el costo J es solo la pérdida promedio, promedio de todo el conjunto de entrenamiento de m ejemplos. Por lo tanto, 1 sobre n multiplicado por la suma de las pérdidas de i es igual a 1 para m. Si agregas la definición de pérdida simplificada vista desde arriba, el resultado es el siguiente: 1 sobre m multiplicado por la suma del término anterior. Si traes los signos negativos y los mueves hacia afuera, el resultado es esta expresión, que es la función de costo.
#
#   ![size vs price](images/regresion_logistica_45.png)
#
#
#   La función de costo que casi todo el mundo usa para entrenar la regresión logística. Quizás se pregunte,
#
#   ¿por qué elegimos esta función en particular cuando podría haber muchas otras funciones de costos que podríamos haber elegido?
#
#    Aunque no tendremos tiempo para entrar en detalles sobre esto en esta clase, me gustaría mencionar que esta función de costo en particular se deriva de las estadísticas que utilizan un principio estadístico llamado estimación de máxima verosimilitud, que es una idea de las estadísticas sobre cómo encontrar de manera eficiente los parámetros para diferentes modelos. Esta función de coste tiene la bonita propiedad de que es convexa. Pero no te preocupes por conocer los detalles de la máxima probabilidad. Es solo un razonamiento y una justificación más profundos detrás de esta función de costos en particular.

# %% [markdown]
# ## Implementación del descenso gradiente
#
# Para ajustar los parámetros de un modelo de regresión logística, trataremos de encontrar los valores de los parámetros w y b que minimizan la función de costo J de w y b, y nuevamente aplicaremos el gradiente de descenso para hacerlo.
#
# Nos centraremos en cómo encontrar una buena elección de los parámetros w y b.
#
#  Una vez hecho esto, si se le da al modelo una nueva entrada, x, por ejemplo, un nuevo paciente en el hospital con un tumor de un tamaño y una edad determinados, entonces se obtiene el diagnóstico.
#
#   A continuación, el modelo puede hacer una predicción o intentar estimar la probabilidad de que la etiqueta y sea una.
#
#   ![size vs price](images/regresion_logistica_46.png)
#
#
#  El promedio que puede usar para minimizar la función de costo es el gradiente de descenso. Aquí nuevamente está la función de costo.
#
# ![size vs price](images/regresion_logistica_47.png)
#
#
# Si quieres minimizar el costo j en función de w y b, bueno, aquí tienes el algoritmo habitual de descenso de gradientes, en el que actualizas repetidamente cada parámetro como el valor 0 menos Alpha, la tasa de aprendizaje multiplicada por este término derivado.
#
#
# ![size vs price](images/regresion_logistica_48.png)
#
#
#  Veamos la derivada de j con respecto a w_j. Este término aparece arriba, donde, como de costumbre, j va del uno al n, donde n es el número de entidades. Si alguien aplicara las reglas del cálculo, podría demostrar que la derivada con respecto a w_j de la función de costo capital J es igual a esta expresión de aquí,
#
#
#  ![size vs price](images/regresion_logistica_49.png)
#
#  es 1 sobre m multiplicado por la suma de 1 a m de este término de error. Eso es f menos la etiqueta y multiplicado por x_j.
#
# Aquí están solo x I j es la función j del ejemplo de entrenamiento i. Ahora veamos también la derivada de j con respecto al parámetro b.
#
#
# ![size vs price](images/regresion_logistica_50.png)

# %% [markdown]
# Resulta que es esta expresión de aquí. Es bastante similar a la expresión anterior, excepto que no se multiplica por este superíndice x i subíndice j al final.
#
#
#  Como recordatorio, al igual que en el caso de la regresión lineal, la forma de llevar a cabo estas actualizaciones consiste en utilizar actualizaciones simultáneas, lo que significa que primero se calcula el lado derecho de todas estas actualizaciones y, a continuación, se sobrescriben simultáneamente todos los valores de la izquierda al mismo tiempo.
#
#
#   Esto le da un gradiente de descenso para la regresión logística. Ahora, una cosa graciosa que te preguntarás es que eso es extraño. Estas dos ecuaciones tienen exactamente el mismo aspecto que el promedio que habíamos obtenido anteriormente para la regresión lineal , así que quizás se pregunte si la regresión lineal es en realidad secretamente lo mismo que la regresión logística.
#
#
#   ![size vs price](images/regresion_logistica_51.png)
#
#
#   Bueno, aunque estas ecuaciones tienen el mismo aspecto, la razón por la que no se trata de una regresión lineal es porque la definición de la función f de x ha cambiado. En la regresión lineal, f de x es wx más b.
#
#
#  ![size vs price](images/regresion_logistica_52.png)
#
#    Pero en la regresión logística, f de x se define como la función sigmoidea aplicada a wx más b
#
#    Cuando hablamos anteriormente sobre el descenso de gradiente para la regresión lineal, viste cómo puedes monitorear un descenso de gradiente para asegurarte de que converge. Puedes aplicar el mismo método a la regresión logística para asegurarte de que también converja.
#
#
#    Cuando hablamos anteriormente sobre el descenso de gradiente para la regresión lineal, viste cómo puedes monitorear un descenso de gradiente para asegurarte de que converge. Puedes aplicar el mismo método a la regresión logística para asegurarte de que también converja.
#
# No voy a profundizar en los detalles de la implementación vectorizada en este vídeo. Pero también puedes obtener más información al respecto y ver el código en los laboratorios opcionales
#
#
# Ahora ya sabe cómo implementar el descenso de gradientes para la regresión logística. Es posible que también recuerde el escalado de características cuando utilizábamos la regresión lineal. Ya viste cómo el escalado de entidades, es decir, escalar todas las entidades para que adopten rangos de valores similares, por ejemplo, entre menos 1 y más 1, puede ayudar a que el gradiente descendente converja más rápido. El escalamiento de entidades aplicado de la misma manera para escalar las distintas entidades para que asuman rangos de valores similares también puede acelerar el descenso del gradiente para la regresión logística.
#
# ![size vs price](images/regresion_logistica_53.png)

# %% [markdown]
# ## El problema del sobreajuste
#
# Ahora ha visto un par de algoritmos de aprendizaje diferentes, la regresión lineal y la regresión logística. Funcionan bien para muchas tareas. Pero a veces, en una aplicación, el algoritmo puede encontrarse con un problema llamado sobreajuste, que puede provocar un rendimiento deficiente.

# %% [markdown]
# Qué es el sobreajuste, así como un problema estrechamente relacionado, casi opuesto, llamado subajuste.
#
# Compartiré con vosotros algunas técnicas para realizar un sobreajuste preciso. En particular, existe un método llamado regularización. Técnica muy útil
#
#
# Entonces, la regularización lo ayudará a minimizar este problema de sobreajuste y a hacer que sus algoritmos de aprendizaje funcionen mucho mejor. Echemos un vistazo a qué es el sobreajuste.
#
# Para ayudarnos a entender qué es el sobreajuste. Echemos un vistazo a algunos ejemplos. Volvamos a nuestro ejemplo original de cómo predecir los precios de la vivienda con regresión lineal. Si desea predecir el precio en función del tamaño de una casa. Para ayudarnos a entender qué es el sobreajuste, veamos un ejemplo de regresión lineal.
#
#
# Volveré a nuestro ejemplo original sobre cómo predecir los precios de la vivienda con regresión lineal. Supongamos que su conjunto de datos tiene este aspecto, en el que la entidad de entrada x es el tamaño de la casa y el valor, y, que está intentando predecir el precio de la casa.
#
#  ![size vs price](images/regresion_logistica_54.png)
#
#
#   Una cosa que puedes hacer es ajustar una función lineal a estos datos. Si lo hace, obtendrá un ajuste en línea recta a los datos que tal vez tenga este aspecto.
#
#    Pero este no es un modelo muy bueno. Al observar los datos, parece bastante claro que a medida que aumenta el tamaño de la casa, el proceso de vivienda se estanca. Este algoritmo no se ajusta muy bien a los datos de entrenamiento.
#
# ![size vs price](images/regresion_logistica_55.png)
#
# El término técnico para esto es que el modelo no se ajusta a los datos de entrenamiento.
#
# Otro término es que el algoritmo tiene un sesgo alto.
#
#  Es posible que hayas leído en las noticias sobre algunos algoritmos de aprendizaje que, lamentablemente, demuestran prejuicios contra ciertas etnias o ciertos géneros. En el aprendizaje automático, el término sesgo tiene varios significados. Revisar los algoritmos de aprendizaje para detectar sesgos basados en características como el género o la etnia es absolutamente fundamental. Pero el término sesgo también tiene un segundo significado técnico, que es el que estoy usando aquí, que es si el algoritmo no se ajusta bien a los datos, lo que significa que ni siquiera es capaz de adaptarse tan bien al conjunto de entrenamiento. Hay un patrón claro en los datos de entrenamiento que el algoritmo simplemente no puede capturar.
#
#
#  Otra forma de entender esta forma de sesgo es como si el algoritmo de aprendizaje tuviera una idea preconcebida muy fuerte, o digamos un sesgo muy fuerte, de que los precios de la vivienda van a ser una función completamente lineal del tamaño a pesar de los datos que indiquen lo contrario. Esta idea preconcebida de que los datos son lineales hace que se ajusten a una línea recta que no se ajusta bien a los datos, lo que da lugar a datos mal ajustados.

# %% [markdown]
#  Ahora, veamos una segunda variación de un modelo, que consiste en insertar una función cuadrática en los datos con dos características, x y x^2, y al ajustar los parámetros W1 y W2, se obtiene una curva que se ajusta un poco mejor a los datos. Tal vez tenga este aspecto. Además, si tuvieras que comprar una casa nueva, eso no está en este conjunto de cinco ejemplos de entrenamiento. Este modelo probablemente funcionaría bastante bien en esa casa nueva. Si sois agentes inmobiliarios, la idea de que queréis que vuestro algoritmo de aprendizaje funcione bien, incluso con ejemplos que no estén en el programa de formación, se denomina generalización.
#
#
# ![size vs price](images/regresion_logistica_56.png)
#
#
# Técnicamente decimos que uno quiere que su algoritmo de aprendizaje generalice bien, lo que significa que debe hacer buenas predicciones incluso con ejemplos nuevos que nunca haya visto antes. Parece que estos modelos cuadráticos no se ajustan perfectamente al conjunto de entrenamiento, pero sí bastante bien. Creo que generalizaría bien a nuevos ejemplos
#
#  Veamos ahora el otro extremo. ¿Qué pasaría si ajustara un polinomio de cuarto orden a los datos? Tiene x, x^2, x^3 y x^4 como entidades. Con este cuarto para el polinomio, puedes ajustar exactamente la curva que pasa por los cinco ejemplos de entrenamiento.
#
# ![size vs price](images/regresion_logistica_57.png)
#
# Puede que obtengas una curva con este aspecto. Esto, por un lado, parece funcionar muy bien al ajustar los datos de entrenamiento porque pasa perfectamente por todos los datos de entrenamiento. De hecho, podrías elegir parámetros que hagan que la función de coste sea exactamente igual a cero, ya que los errores son cero en los cinco ejemplos de entrenamiento. Pero esta es una curva muy ondulada, que sube y baja por todas partes. Si tienes todo este tamaño aquí, el modelo predeciría que esta casa es más barata que las casas más pequeñas que ella. No creemos que este sea un modelo particularmente bueno para predecir los precios de la vivienda. El término técnico es que diremos que este modelo tiene un sobreajuste de los datos o que este modelo tiene un problema de sobreajuste.
#
# Porque, aunque se ajusta muy bien al conjunto de entrenamiento, se ajusta casi demasiado bien a los datos, por lo que está sobreajustado. No parece que este modelo vaya a generalizarse a nuevos ejemplos que nunca se hayan visto antes
#
#  Otro término para esto es que el algoritmo tiene una varianza alta. En el aprendizaje automático, muchas personas utilizarán los términos sobreajuste y alta varianza casi indistintamente. Usaremos los términos «subajuste» y «sesgo alto» casi indistintamente. La intuición detrás del sobreajuste o alta varianza es que el algoritmo se esfuerza mucho por adaptarse a cada ejemplo de entrenamiento. Resulta que si tu conjunto de entrenamiento fuera solo un poco diferente, por ejemplo, un hoyo tuviera un precio un poco más alto y un poco menos, entonces la función a la que se ajusta el algoritmo podría terminar siendo totalmente diferente.
#
# ![size vs price](images/regresion_logistica_58.png)
#
#
# Si dos ingenieros de aprendizaje automático ajustaran este modelo polinomial de cuarto orden a conjuntos de datos ligeramente diferentes, no podrían obtener predicciones totalmente diferentes o predicciones muy variables.
#
#
# ![size vs price](images/regresion_logistica_59.png)
#
# Por eso decimos que el algoritmo tiene una varianza alta. Al comparar este modelo situado más a la derecha con el del centro para la misma casa , parece que el modelo central les da una predicción del precio mucho más razonable. En realidad, no hay un nombre intermedio para este caso, pero voy a llamarlo correctamente, porque no es ni demasiado adecuado ni demasiado adecuado. Se puede decir que el objetivo del aprendizaje automático es encontrar un modelo que, con suerte, no sea insuficiente ni demasiado adecuado. En otras palabras, con suerte, un modelo que no tenga ni un sesgo ni una varianza altos. Cuando pienso en un ajuste insuficiente y un sobreajuste, un sesgo alto y una varianza alta.
#
# A veces me acuerdo del cuento infantil de Ricitos de oro y los tres osos. En este cuento infantil, una niña llamada Ricitos de oro visita la casa de una familia de osos. Hay un tazón de gachas que está demasiado frío para probarlo, así que eso no es bueno. También hay un tazón de gachas que está demasiado caliente para comerlo. Eso tampoco está bien. Pero hay un tazón de gachas que no está ni demasiado frío ni demasiado caliente. La temperatura está en el medio, lo cual es justo para comer.
#
#
# En resumen, si tiene demasiadas características, como el polinomio de cuarto orden de la derecha, entonces el modelo puede ajustarse bien al conjunto de entrenamiento, pero casi demasiado bien, o estar sobreajustado y tener una varianza alta. Por otro lado, si tiene muy pocas entidades, en este ejemplo, al igual que en el de la izquierda, no se ajusta correctamente y tiene un sesgo elevado. En este ejemplo, usar las entidades cuadráticas x y x al cuadrado, parece que es lo correcto. Hasta ahora hemos analizado el subajuste y el sobreajuste del modelo de regresión lineal. Del mismo modo, el sobreajuste también aplica una clasificación. Este es un ejemplo de clasificación con dos características, x_1 y x_2, donde x_1 es quizás el tamaño del tumor y x_2 es la edad del paciente. Estamos intentando clasificar si un tumor es maligno o benigno.
#
# Como indican estas cruces y círculos, una de las cosas que podemos hacer es ajustar un modelo de regresión logística.
#
#
# ![size vs price](images/regresion_logistica_60.png)
#
#
#  Un modelo simple como este, en el que, como de costumbre, g es la función sigmoidea y este término que está dentro es z. Si lo haces, terminarás con una línea recta como límite de decisión. Esta es la línea en la que z es igual a cero que separa los ejemplos positivo y negativo. Esta línea recta no tiene mala pinta. Se ve bien, pero tampoco parece que se ajuste muy bien a los datos. Este es un ejemplo de falta de ajuste o de sesgo elevado.
#
#
#
#  Veamos otro ejemplo. Si tuvieras que añadir a tus entidades estos términos cuadráticos, z se convertiría en este nuevo término situado en el centro y el límite de decisión, es decir, donde z es igual a cero, podría tener un aspecto más parecido a este, más parecido a una elipse o parte de una elipse.
#
#  ![size vs price](images/regresion_logistica_61.png)
#
#  Se ajusta bastante bien a los datos, aunque no clasifique perfectamente todos los ejemplos de entrenamiento del conjunto de entrenamiento. Observa cómo algunas de estas cruces se clasifican entre los círculos. Pero este modelo se ve bastante bien. Voy a llamarlo de la manera correcta. Parece que esto se ha generalizado bastante bien a los pacientes nuevos.
#
#
# Por último, en el otro extremo, si tuvieras que ajustar un polinomio de orden muy alto con muchas características como estas, entonces el modelo podría esforzarse mucho y contornearse o torcerse para encontrar un límite de decisión que se ajuste perfectamente a tus datos de entrenamiento.
#
#   ![size vs price](images/regresion_logistica_62.png)
#
#
#    Al disponer de todas estas características polinómicas de orden superior, el algoritmo puede elegirlo realmente en lugar del complejo límite de decisión. Si las características son el tamaño del tumor en función de la edad y se intenta clasificar los tumores como malignos o benignos, no se trata realmente de un modelo muy bueno para hacer predicciones. Una vez más, este es un caso de sobreajuste y alta varianza porque su modelo, a pesar de funcionar muy bien en el conjunto de entrenamiento, no parece que vaya a generalizarse bien a nuevos ejemplos

# %% [markdown]
# ## Abordar la sobreadaptación
#
# Más adelante en esta especialización, hablaremos sobre la depuración y el diagnóstico de cosas que pueden salir mal con los algoritmos de aprendizaje. También conocerás herramientas específicas para reconocer cuándo puede estar ocurriendo un ajuste excesivo o insuficiente
#
#  Pero por ahora, si crees que se ha producido un sobreajuste, hablemos de lo que puedes hacer para solucionarlo. Supongamos que se ajusta a un modelo y éste tiene una gran varianza, es decir, está sobreajustado.
#
#
#   Este es nuestro modelo de predicción del precio de una vivienda con sobreajuste.
#
#   ![size vs price](images/regresion_logistica_63.png)
#
#   Una forma de abordar este problema es recopilar más datos de entrenamiento, esa es una opción. Si puedes obtener más datos, es decir, más ejemplos de entrenamiento sobre el tamaño y el precio de las casas, entonces, con un conjunto de entrenamiento más grande, el algoritmo de aprendizaje aprenderá a ajustar una función que sea menos variable.
#
# ![size vs price](images/regresion_logistica_64.png)
#
# Puedes seguir ajustando un polinomio de orden superior o alguna de las funciones con muchas funciones y, si tienes suficientes ejemplos de entrenamiento, seguirá funcionando bien. En resumen,  **la herramienta número uno que puedes usar contra el sobreajuste es obtener más datos de entrenamiento.**  Ahora bien, obtener más datos no siempre es una opción. Tal vez solo se hayan vendido un número limitado de casas en esta ubicación, así que tal vez no haya más datos para agregar. Pero cuando los datos están disponibles, esto puede funcionar muy bien. Una segunda opción para abordar el sobreajuste es comprobar si se pueden utilizar menos funciones. En el vídeo anterior, las características de nuestros modelos incluían el tamaño x, así como el tamaño al cuadrado, y este x al cuadrado, x al cubo y x^4 y así sucesivamente.
#
#
# Eran muchos elementos polinomiales. En ese caso, una forma de reducir el sobreajuste es simplemente no utilizar tantas de estas entidades polinomiales. Pero ahora veamos un ejemplo diferente.
#
# ![size vs price](images/regresion_logistica_65.png)
#
#  Tal vez una casa tenga muchas características diferentes para intentar predecir su precio, desde el tamaño, el número de dormitorios, el número de pisos, la antigüedad, el ingreso promedio del vecindario, etc., hasta la distancia total a la cafetería más cercana. Resulta que si tienes muchas funciones como estas pero no tienes suficientes datos de entrenamiento, es posible que tu algoritmo de aprendizaje también se adapte demasiado a tu conjunto de entrenamiento. Ahora, en lugar de usar las 100 funciones, si tuviéramos que elegir solo un subconjunto de las más útiles, tal vez el tamaño, los dormitorios y la antigüedad de la casa. Si cree que esas son las características más relevantes y, si utiliza solo el subconjunto más pequeño de características, es posible que descubra que su modelo ya no se ajusta tan demasiado.
#
#  La elección del conjunto de funciones más apropiado para su uso a veces también recibe el nombre de selección de funciones. Una forma de hacerlo es usar tu intuición para elegir el mejor conjunto de funciones que consideres el mejor, lo más relevante para predecir el precio.
#
#  . Ahora bien, una desventaja de la selección de características es que, al usar solo un subconjunto de las características, el algoritmo desecha parte de la información que se tiene sobre las casas. Por ejemplo, tal vez todas estas características, las 100, sean realmente útiles para predecir el precio de una casa. Tal vez no quieras desperdiciar parte de la información desechando algunas de las funciones. Más adelante, en el curso 2, también verás algunos algoritmos para elegir automáticamente el conjunto de funciones más apropiado para usar en nuestra tarea de predicción. Ahora, esto nos lleva a la tercera opción para reducir el sobreajuste.
#
#
#  Esta técnica, que analizaremos con aún mayor profundidad, se llama regularización. Si observas un modelo sobreajustado, aquí tienes un modelo que usa características polinomiales: x, x al cuadrado, x al cubo, etc.
#
#
#   Descubrirás que los parámetros suelen ser relativamente grandes. Ahora bien, si se eliminaran algunas de estas características, por ejemplo, si se eliminara la función x4, eso correspondería a establecer este parámetro en 0. Por lo tanto, establecer un parámetro en 0 equivale a eliminar una función, que es lo que vimos anteriormente. Resulta que la regularización es una forma de reducir más suavemente el impacto de algunas de las funciones sin hacer algo tan duro como eliminarlas por completo. Lo que hace la regularización es fomentar que el algoritmo de aprendizaje reduzca los valores de los parámetros sin exigir necesariamente que el parámetro se establezca exactamente en 0.
#
#  ![size vs price](images/regresion_logistica_66.png)
#
#
#  Resulta que incluso si ajustas un polinomio de orden superior como este, siempre que puedas hacer que el algoritmo utilice valores de parámetros más pequeños: w1, w2, w3, w4. Terminas con una curva que acaba ajustándose mucho mejor a los datos de entrenamiento.
#
#
#  ![size vs price](images/regresion_logistica_67.png)
#
#  Lo que hace la regularización es conservar todas las características, pero solo evita que las entidades tengan un efecto demasiado grande, que es lo que a veces puede provocar un sobreajuste. Por cierto, por convención, normalmente reducimos el tamaño de los parámetros wj, es decir, de w1 a wn. No hay mucha diferencia entre regularizar también el parámetro b, puedes hacerlo si quieres o no si no lo haces. Por lo general, no lo hago y está bien regularizar w1, w2, hasta ganar, pero no alentar realmente a b a reducir su tamaño. En la práctica, no debería haber mucha diferencia entre regularizar b o no. En resumen, estas son las tres formas para abordar el sobreajuste.
#
# * En resumen:
#     1. Recopilar más datos. Si puede obtener más datos, esto realmente puede ayudar a reducir el sobreajuste. A veces eso no es posible.
#     2. Intentar seleccionar y utilizar solo un subconjunto de las funciones. Obtendrá más información sobre la selección de funciones en el curso 2.
#     3. Reducir el tamaño de los parámetros mediante la regularización.
#
#
# Consideraciones para el siguiente laboratorio:
#
# Solo para mí, uso la regularización todo el tiempo. Por lo tanto, esta es una técnica muy útil para entrenar algoritmos de aprendizaje, incluidas específicamente las redes neuronales, que también veremos más adelante en esta especialización. Espero que también consultes el laboratorio opcional sobre sobreajuste. En el laboratorio, podrás ver diferentes ejemplos de sobreajuste y ajustarlos haciendo clic en las opciones de los gráficos.
#
# ![size vs price](images/regresion_logistica_68.png)
#
# También podrás añadir tus propios puntos de datos haciendo clic en la gráfica y ver cómo eso cambia la curva en la que se ajusta.
#
# ![size vs price](images/regresion_logistica_69.png)
#
#
# También puedes probar ejemplos de regresión y clasificación y cambiarás el grado del polinomio para que sea x, x al cuadrado, x al cubo, etc. El laboratorio también te permite jugar con dos opciones diferentes para abordar el sobreajuste.
#
# ![size vs price](images/regresion_logistica_70.png)
#
# Puedes añadir datos de entrenamiento adicionales para reducir el sobreajuste y también puedes seleccionar qué características quieres incluir o excluir como otra forma de intentar reducir el sobreajuste. Por favor, echa un vistazo a un laboratorio, que espero te ayude a desarrollar tu intuición sobre el sobreajuste, así como algunos métodos para abordarlo.

# %% [markdown]
# ## Función de costes con regularización
#
#
# Anteriormente vimos que la regularización intenta reducir los valores parentales W1 a WN para reducir el sobreajuste. En este punto, nos basaremos en esa intuición y desarrollaremos una función de coste modificada para su algoritmo de aprendizaje que pueda utilizar para aplicar realmente la regularización
#
# Empecemos y recordemos este ejemplo en el que vimos que si se ajusta una función cuadrática a estos datos, se obtiene un ajuste bastante bueno. Pero si se ajusta a un polinomio de orden muy alto, se obtiene una curva que sobreajusta los datos.
#
# ![size vs price](images/regresion_logistica_71.png)
#
# Pero ahora consideremos lo siguiente: supongamos que tenemos una forma de hacer que los parámetros W3 y W4 sean muy, muy pequeños. Diga cerca de 0. Esto es lo que quiero decir.
#
# Digamos que en vez de minimizar esta función objetivo, esta es una función de costo para la regresión lineal.
#
# ![size vs price](images/regresion_logistica_72.png)
#
# Supongamos que modificamos la función de costo y le sumamos 1000 veces W3 al cuadrado más 1000 veces W4 al cuadrado. Y aquí elijo 1000 porque es un número grande, pero cualquier otro número muy grande estaría bien. Por lo tanto, con esta función de costo modificada, podrías estar penalizando al modelo si W3 y W4 son grandes. Porque si quieres minimizar esta función, la única forma de reducir esta nueva función de coste es si W3 y W4 son ambos pequeños, ¿verdad? Porque si no, estos términos cuadrados de 1000 veces W3 al cuadrado y 1000 veces W4 van a ser muy, muy grandes. Así que cuando minimices esta función, terminarás con W3 cerca de 0 y W4 cerca de 0.

# %% [markdown]
# # Clasificación

# %% [markdown]
#  Resulta que la regresión lineal no es un buen algoritmo para los problemas de clasificación. Veamos por qué y esto nos llevará a un algoritmo diferente llamado regresión logística.

# %% [markdown]
# ### Regresión logística.

# %% [markdown]
# Cuál es uno de los algoritmos de aprendizaje más populares y utilizados en la actualidad. Estos son algunos ejemplos de problemas de clasificación:
#
# ![size vs price](images/regresion_logistica_01.png)

# %% [markdown]
# Este tipo de problema de clasificación en el que solo hay dos salidas posibles se denomina **clasificación binaria** Donde la palabra binario se refiere a que solo hay dos clases o dos categorías posibles.

# %% [markdown]
# Por lo general, utilizo los números cero y uno para representar la respuesta y, porque eso encajará más fácilmente con los tipos de algoritmos de aprendizaje que queremos implementar. Pero cuando hablamos de ello, a menudo decimos que no o que sí, o que también es falso o verdadero. Una de las tecnologías más utilizadas es la de denominar a la clase falsa o cero.

# %% [markdown]
# ![size vs price](images/regresion_logistica_01.png)

# %% [markdown]
# ## Regresión Logística

# %% [markdown]
# vio que la regresión lineal no es un buen algoritmo para este problema. Por el contrario, lo que hacemos con la regresión logística es ajustar una curva parecida a esta curva en forma de S a este conjunto de datos. En este ejemplo, si un paciente llega con un tumor de este tamaño, que estoy mostrando en el eje x, el algoritmo arrojará un resultado de 0.7, lo que sugiere que está más cerca o tiene más probabilidades de ser maligno y benigno.

# %% [markdown]
# ![size vs price](images/regresion_logistica_02.png)

# %% [markdown]
# En el primer paso, espero que recuerdes que una función de línea recta, como una función de regresión lineal, se puede definir como un producto de x más b. Almacenemos este valor en una variable a la que llamaré z, y resultará ser la misma z que la que viste en la diapositiva anterior, pero lo veremos en un minuto.

# %% [markdown]
# ![size vs price](images/regresion_logistica_04.png)

# %% [markdown]
# El siguiente paso es tomar este valor de z y pasarlo a la función sigmoidea, también llamada función logística, g. Ahora, g de z produce un valor calculado con esta fórmula, 1 sobre 1 más e elevado a z negativo. Va a haber entre 0 y 1. Cuando tomas estas dos ecuaciones y las juntas, obtienes el modelo de regresión logística f de x, que es igual a g de wx más b. O equivalentemente g de z, que es igual a esta fórmula de aquí. Este es el modelo de regresión logística, y lo que hace es introducir una entidad o conjunto de entidades X y generar un número entre 0 y 1. A continuación, veamos cómo interpretar el resultado de la regresión logística.

# %% [markdown]
# Volveremos al ejemplo de clasificación de tumores. La forma en que les animo a pensar en el resultado de las regresiones logísticas es pensar en ello como la probabilidad de que la clase o la etiqueta y sea igual a 1 dada una determinada entrada x. Por ejemplo, en esta aplicación, donde x es el tamaño del tumor e y es 0 o 1, si entra una paciente y tiene un tumor de un tamaño determinado x, y si se basa en esta entrada x, el modelo yo añadiré 0.7 entonces lo que eso significa es que el modelo está prediciendo o el modelo cree que hay un 70 por ciento de probabilidades de que la verdadera etiqueta y sea igual a 1 para este paciente. En otras palabras, el modelo nos dice que cree que el paciente tiene un 70 por ciento de probabilidades de que el tumor se convierta en maligno.

# %% [markdown]
# ![size vs price](images/regresion_logistica_05.png)

# %% [markdown]
# Así que y tiene que ser 0 o 1 y, por lo tanto, la probabilidad de que sea 0 o 1 estos dos números tienen que sumar uno o una probabilidad del 100 por ciento. Por eso, si la probabilidad de que y sea 1 es del 0,7 o del 70 por ciento, entonces la probabilidad de que sea 0 tiene que ser del 0,3 o el 30 por ciento. Si algún día lees artículos de investigación o reseñas de blogs sobre todas las regresiones logísticas, a veces verás esta notación según la cual f de x es igual a p de y es igual a 1 dadas las entidades de entrada x y con los parámetros w y b. Lo que se usa aquí con el punto y coma es que w y b son parámetros que afectan al cálculo de cuál es la probabilidad de que y sea igual a 1 dada la entidad de entrada x. Para el propósito de esta clase, no te preocupes demasiado por el significado de esta línea vertical y el punto y coma.

# %% [markdown]
# ![size vs price](images/regresion_logistica_06.png)

# %% [markdown]
# Laboratorio: C1_W3_Lab02_Sigmoid_function_Soln.ipynb

# %% [markdown]
# ## Limite de desicion (Decision Boundary)
#
#  Ahora, echemos un vistazo al límite de decisión para tener una mejor idea de cómo la regresión logística calcula estas predicciones.
# En resumen, aquí se explica cómo se calculan los resultados de los modelos de regresión logística en dos pasos.
#
# 1.-En el primer paso, calculamos z como w.x más b. A continuación, aplicamos la función sigmoidea g a este valor z.
#
# ![size vs price](images/regresion_logistica_07.png)
#
# También aquí tenemos la fórmula de la función sigmoidea.
#
# ![size vs price](images/regresion_logistica_08.png)
#
# Otra forma de escribir esto es decir que f de x es igual a g, la función sigmoidea, también llamada función logística, aplicada a w.x más b, donde este es, por supuesto, el valor de z.
# ![size vs price](images/regresion_logistica_10.png)

# %% [markdown]
# Si tomas la definición de la función sigmoidea y agregas la definición de z, entonces encontrarás que f de x es igual a esta fórmula de aquí, 1 sobre 1 más e al negativo z, donde z es wx más b.

# %% [markdown]
#  Tal vez recuerdes con anterioridad que interpretamos esto como la probabilidad de que y sea igual a 1 dada x y con parámetros w y b.
#
#  ![size vs price](images/regresion_logistica_11.png)
#
#  Será un número como 0.7 o 0.3. Ahora, ¿qué pasa si quieres aprender el algoritmo para predecir? ¿El valor de y va a ser cero o uno? Bueno, una cosa que puedes hacer es establecer un umbral por encima del cual puedas predecir que y es uno, o establecer que la predicción sea igual a uno y por debajo del cual puedes decir que mi predicción va a ser igual a cero. Una opción común sería elegir un umbral de 0.5 para que si f de x es mayor o igual a 0.5, entonces predecir y sea uno.
#
#   ![size vs price](images/regresion_logistica_12.png)
#
#   Escribimos esa predicción como y que es igual a 1, o si f de x es menor que 0,5, entonces predecimos y es 0
#
#    ![size vs price](images/regresion_logistica_13.png)

# %% [markdown]
# En otras palabras, cuando f de x es mayor o igual a 0.5. Recordaremos que f de x es igual a g de z. Por lo tanto, f es mayor o igual a 0.5 siempre que g de z sea mayor o igual a 0.5. Pero, ¿cuándo es g de z mayor o igual a 0.5? Bueno, aquí hay una función sigmoidea.

# %% [markdown]
# Así que g de z es mayor o igual a 0.5 siempre que z sea mayor o igual a 0. Es decir, siempre que z esté en la mitad derecha de este eje. Finalmente, ¿cuándo z es mayor o igual a cero? Bueno, z es igual a w.x más b, así que z es mayor o igual a cero siempre que w.x más b sea mayor o igual a cero. En resumen, lo que ha visto aquí es que el modelo predice 1 siempre que w.x más b sea mayor o igual a 0. Por el contrario, cuando w.x más b es menor que cero, el algoritmo predice que y es 0.
#
#  ![size vs price](images/regresion_logistica_14.png)

# %% [markdown]
# Voy a tomar un ejemplo de un problema de clasificación en el que hay dos entidades, x1 y x2, en lugar de una sola entidad. He aquí un conjunto de entrenamiento en el que las pequeñas cruces rojas indican los ejemplos positivos y los pequeños círculos azules indican los negativos. Las cruces rojas corresponden a y es igual a 1, y los círculos azules corresponden a y es igual a 0.
#
#  ![size vs price](images/regresion_logistica_15.png)

# %% [markdown]
# El modelo de regresión logística hará predicciones usando esta función f de x igual a g de z, donde z es ahora esta expresión, w1x1 más w2x2 más b, porque tenemos dos características x1 y x2. Supongamos, para este ejemplo, que el valor de los parámetros es w1 igual a 1, w2 es igual a 1 y b es igual a menos 3. Veamos ahora cómo la regresión logística hace predicciones. En particular, averigüemos cuándo wx más b es mayor que igual a 0 y cuándo wx más b es menor que 0.
#
#  ![size vs price](images/regresion_logistica_16.png)

# %% [markdown]
# Para averiguarlo, hay una línea muy interesante que observar, que es cuando wx más b es exactamente igual a 0. Resulta que esta línea también se llama límite de decisión porque es la línea en la que eres casi neutral en cuanto a si y es 0 o y es 1. Ahora, para los valores de los parámetros w_1, w_2 y b que habíamos anotado anteriormente, este límite de decisión es simplemente x_1 más x_2 menos 3. ¿Cuándo x_1 más x_2 menos 3 es igual a 0? Bueno, eso corresponderá a la línea x_1 más x_2 igual a 3, y esa es la línea que se muestra aquí. Esta línea resulta ser el límite de decisión, donde si las entidades x están a la derecha de esta línea, la regresión logística predeciría 1 y, a la izquierda de esta línea, la regresión logística con predice 0. En otras palabras, lo que acabamos de visualizar es el límite de decisión para la regresión logística cuando los parámetros w_1, w_2 y b son 1,1 y menos 3.
#
#  ![size vs price](images/regresion_logistica_18.png)

# %% [markdown]
# Veamos ahora un ejemplo más complejo en el que el límite de decisión ya no es una línea recta. Como antes, las cruces indican que la clase y es igual a 1, y los círculos pequeños indican que la clase y es igual a 0.
#
# ![size vs price](images/regresion_logistica_19.png)

# %% [markdown]
#  A principios de la semana pasada, vio cómo usar polinomios en la regresión lineal, y puede hacer lo mismo en la regresión logística. Esto establece que z sea w_1, x_1 al cuadrado más w_2, x_2 al cuadrado más b. Con esta selección de entidades, las entidades polinomiales forman una regresión logística. La F de x, que es igual a g de z, ahora es la g de esta expresión de aquí.
#
# ![size vs price](images/regresion_logistica_20.png)
#
#  Digamos que acabamos eligiendo w_1 y w_2 como 1 y b como menos 1. Z es igual a 1 por x_1 al cuadrado más 1 por x_2 al cuadrado menos 1. El límite de decisión, como antes, corresponderá a cuando z sea igual a 0. Esta expresión será igual a 0 cuando x_1 al cuadrado más x_2 al cuadrado sea igual a 1. Si graficas en el diagrama de la izquierda, la curva correspondiente a x_1 al cuadrado más x_2 al cuadrado es igual a 1, resulta ser el círculo. Cuando x_1 al cuadrado más x_2 al cuadrado es mayor o igual a 1, esa es el área situada fuera del círculo y es entonces cuando se predice que y será 1. Por el contrario, cuando x_1 al cuadrado más x_2 al cuadrado es menor que 1, esa es el área dentro del círculo y ahí es cuando se predice que y será 0.

# %% [markdown]
# ¿Podemos crear límites de decisión aún más complejos que estos? Sí, puedes. Puedes hacerlo si tienes términos polinomiales de orden aún mayor. Supongamos que z es w_1, x_1 más w_2, x_2 más w_3, x_1 al cuadrado más w_4, x_1, x_2 más w_5, x_2 al cuadrado. Entonces es posible obtener límites de decisión aún más complejos. El modelo puede definir los límites de decisión, como en este ejemplo, una elipse como esta o con una selección diferente de los parámetros. Incluso puede obtener límites de decisión más complejos, que pueden tener el aspecto de funciones que tal vez tengan ese aspecto.
#
# ![size vs price](images/regresion_logistica_22.png)
#
#
# Así que este es un ejemplo de un límite de decisión aún más complejo que los que hemos visto anteriormente. Esta implementación de la regresión logística predecirá que y es igual a 1 dentro de esta forma y fuera de la forma predecirá y es igual a 0.

# %% [markdown]
# Con estas características polinomiales, puede obtener límites de decisión muy complejos. En otras palabras, la regresión logística puede aprender a ajustar datos bastante complejos. Sin embargo, si no incluyera ninguno de estos polinomios de orden superior, si las únicas entidades que utiliza son x_1, x_2, x_3, etc., el límite de decisión para la regresión logística siempre será lineal, siempre será una línea recta. En el próximo laboratorio opcional, también podrás ver la implementación en código del límite de decisión.

# %% [markdown]
# ## Funcion de costo para Regresion Logistica

# %% [markdown]
# Recuerde que la función de costo le brinda una forma de medir qué tan bien un conjunto específico de parámetros se ajusta a los datos de entrenamiento.  De este modo, le brinda una forma de intentar elegir mejores parámetros.

# %% [markdown]
#  veremos cómo la función de coste del error cuadrático no es una función de coste ideal para la regresión logística.
#
#
#   Este es el aspecto que podría tener el conjunto de entrenamiento para nuestro modelo de regresión logística. Aquí cada fila podría corresponder a un paciente que estaba visitando al médico y otro tenía algún diagnóstico. Como antes, usaremos m para indicar el número de ejemplos de entrenamiento.
#
#   ![size vs price](images/regresion_logistica_23.png)

# %% [markdown]
# Cada ejemplo de entrenamiento tiene una o más características, como el tamaño del tumor, la edad del paciente, etc., para un total de n características. Llamemos a las entidades X_1 a X_n. Como se trata de una tarea de clasificación binaria, la etiqueta objetivo y solo toma dos valores, 0 o 1.

# %% [markdown]
# Por último, el modelo de regresión logística se define mediante esta ecuación.
#
#  ![size vs price](images/regresion_logistica_24.png)
#
#  La pregunta que desea responder es, dado este conjunto de entrenamiento, ¿cómo puede elegir los parámetros w y b? Recuerde que para la regresión lineal, esta es la función de costo del error cuadrático. Lo único que cambié es que puse la mitad dentro de la suma en lugar de fuera de la suma.
#
#  ![size vs price](images/regresion_logistica_25.png)

# %% [markdown]
# Tal vez recuerdes que en el caso de la regresión lineal, donde f de x es la función lineal, w punto x más b.
#
# ![size vs price](images/regresion_logistica_26.png)
#
# La función de coste tiene este aspecto, es una función convexa o una forma de cuenco o de martillo.
#
# ![size vs price](images/regresion_logistica_27.png)
#
#
#  El gradiente descendiente tendrá este aspecto, en el que se da un paso, un paso, etc. para converger en el mínimo global. Ahora puede intentar usar la misma función de costo para la regresión logística.
#
#  ![size vs price](images/regresion_logistica_28.png)

# %% [markdown]
# Pero resulta que si escribo f de x igual a 1 sobre 1 más e, a menos wx más b y grafico la función de costo usando este valor de f de x, entonces el costo se vería así. Esto se convierte en lo que se llama una función de costo no convexa, no es convexa. Lo que esto significa es que si intentaras usar el gradiente de descenso.
#
#  ![size vs price](images/regresion_logistica_29.png)
#
#
#  Hay muchos mínimos locales que puedes llegar a ser pésimos. Resulta que para la regresión logística, esta función de coste de error cuadrático no es una buena opción.
#
#   En cambio, habrá una función de costo diferente que puede hacer que la función de costo vuelva a ser convexa.
#
#   Se puede garantizar que el descenso del gradiente converja al mínimo global. Lo único que cambié es que puse la mitad dentro de la suma en lugar de fuera de la suma. Esto simplificará un poco los cálculos que verás más adelante en esta diapositiva. Para crear una nueva función de costo, una que usaremos para la regresión logística.

# %% [markdown]
# Voy a cambiar un poco la definición de la función de coste J de w y b. En concreto, si analizamos esta suma, llamemos a este término dentro de la pérdida en un solo ejemplo de entrenamiento.
#
#  ![size vs price](images/regresion_logistica_30.png)
#
# Voy a denotar la pérdida mediante esta L mayúscula y, en función de la predicción del algoritmo de aprendizaje, f de x, así como de la etiqueta verdadera y. La pérdida dada el predictor f de x y la verdadera etiqueta y es igual en este caso a 1,5 de la diferencia al cuadrado. Veremos en breve que, al elegir una forma diferente para esta función de pérdida, podremos mantener la función de costo general, que es 1 sobre n veces la suma de estas funciones de pérdida, en una función convexa.
#
#
# Ahora, la función de pérdida introduce f de x y la etiqueta verdadera y, y nos indica qué tan bien nos va con ese ejemplo. Voy a escribir aquí la definición de la función de pérdida que usaremos para la regresión logística.
#
# ![size vs price](images/regresion_logistica_31.png)
#
# Si la etiqueta y es igual a 1, entonces la pérdida es el logaritmo negativo de f de x y si la etiqueta y es igual a 0, entonces la pérdida es el logaritmo negativo de 1 menos f de x.

# %% [markdown]
#  Veamos por qué esta función de pérdida, ojalá tenga sentido. Consideremos primero el caso en el que y es igual a 1 y representemos gráficamente el aspecto de esta función para hacernos una idea de lo que hace esta función de pérdida. Recuerda que la función de pérdida mide tu rendimiento en un ejemplo de entrenamiento y consiste en sumar las pérdidas de todos los ejemplos de entrenamiento que obtengas, la función de coste, que mide tu rendimiento en todo el conjunto de entrenamiento. Si graficas el logaritmo de f, se ve como esta curva, donde f está en el eje horizontal. Una gráfica de un negativo del logaritmo de f se ve así, en la que simplemente volteamos la curva a lo largo del eje horizontal. Observa que se cruza con el eje horizontal cuando f es igual a 1 y continúa hacia abajo desde allí.
#
#  ![size vs price](images/regresion_logistica_32.png)

# %% [markdown]
# Ahora, f es el resultado de la regresión logística. Por lo tanto, f siempre está entre cero y uno porque el resultado de la regresión logística siempre está entre cero y uno. Por lo tanto, la única parte de la función que es relevante es esta parte de aquí, que corresponde a f entre 0 y 1. Acerquemos la imagen y veamos más de cerca esta parte del gráfico. Si el algoritmo predice una probabilidad cercana a 1 y la etiqueta verdadera es 1, entonces la pérdida es muy pequeña. Es prácticamente 0 porque estás muy cerca de la respuesta correcta. Ahora continúa con el ejemplo de que la etiqueta verdadera y es 1, supongamos que todo es un tumor maligno.
#
# ![size vs price](images/regresion_logistica_33.png)

# %% [markdown]
# ## Supervised Learning
#
# Se refiere a los algoritmos que aprenden mapeos de x a y o de entrada a salida.
# La caracteristica clave del aprendizaje supervisado es que le das a tu algoritmo de aprendizaje ejemplos de los que aprender.
#
# Esto incluye las respuestas correctas, es decir la etiqueta correcta 'y' para una entrada 'x',  y es viendo los pares correctos de la entrada 'x' y la etiqueta  de salida deseada 'y', como el algoritmo de aprendizaje finalmente aprende  a tomar solo la entrada sin la etiqueta de salida y proporciona una predicción o una suposición razonablemente precisa del resultado

# %% [markdown]
# + ####  Algoritmo de Regresion
#
# Supongamos que quieres predecir los precios de la vivienda en funcion del tamaño de la casa. Has recopilado algunos datos y dices que trazas los datos y se ve así:
#
# ![size vs price](images/house_data_test.png)
#
#
# Una cosa que un algoritmo de aprendizaje podría hacer es decir que si se obtiene la línea recta con los datos y se lee a partir de la línea recta, parece que la casa de tu amigo podría venderse por unos, no sé, 150.000 dólares.
#
# ![size vs price](images/house_data_test_1.png)
#
# Por ejemplo, al enrutar y ajustar una línea recta, podrías decidir que es mejor ajustar una curva, una función que es un poco más complicada o compleja que una línea recta. Si haces eso y haces una predicción aquí, entonces parece que, bueno, la casa de tu amigo podría venderse por cerca de 200 000$
#
# ![size vs price](images/house_data_test_2.png)
#
# La tarea del algoritmo de aprendizaje es producir más de estas respuestas correctas, específicamente predecir cuál es el precio probable de otras casas, como la casa de un amigo. Por eso se trata de un aprendizaje supervisado. Para definir un poco más la terminología, esta predicción del precio de la vivienda es el tipo particular de aprendizaje supervisado llamado regresión. Por regresión, quiero decir que estamos intentando predecir un número a partir de un número infinito de números posibles, como los precios de la vivienda en nuestro ejemplo, que podrían ser 150 000, 70 000, 183 000 o cualquier otro número intermedio.

# %% [markdown]
# + #### Algoritmo de Clasification
#
#
# Tomemos la detección del cáncer de mama como ejemplo de un problema de clasificación. Supongamos que está creando un sistema de aprendizaje automático para que los médicos puedan disponer de una herramienta de diagnóstico para detectar el cáncer de mama. Esto es importante porque la detección temprana podría salvar la vida de un paciente. Con la historia clínica de un paciente, su sistema de aprendizaje automático intenta averiguar si un tumor, que es un bulto, es maligno, es decir, canceroso o peligroso.
#
# Y estos tumores se clasifican como benignos, que designaré en este ejemplo con un 0, o como malignos, que designaremos en este ejemplo con un 1.
#
# Una razón por la que esto difiere de la regresión es que estamos intentando predecir solo una pequeña cantidad de resultados o categorías posibles. En este caso, dos posibles resultados: 0 o 1, benignos o malignos.
#
# Esto es diferente de la regresión, que intenta predecir cualquier número, todos los números infinitos posibles.
#
# ![size vs price](images/cancer.png)
#
#
#  Entonces, lo que digo clase o categoría cuando me refiero a la salida significa lo mismo. Así que, para resumir, los algoritmos de clasificación predicen categorías. Las categorías no tienen que ser números. Puede no ser numérico, por ejemplo, puede predecir si una imagen es la de un gato o un perro. Y puede predecir si un tumor es benigno o maligno. Las categorías también pueden ser números como 0, 1 o 0, 1, 2. Pero lo que diferencia a la clasificación de la regresión cuando se interpretan los números es que la clasificación predice un conjunto pequeño y limitado de posibles categorías de salida, como 0, 1 y 2, pero no todos los números posibles intermedios, como 0,5 o 1,7.
#
#
# ![size vs price](images/cancer_01.png)
#
#
#  Este es un ejemplo: en lugar de solo conocer el tamaño del tumor, supongamos que también tiene la edad de cada paciente en años. Su nuevo conjunto de datos ahora tiene dos entradas: la edad y el tamaño del tumor.
#
#  ![size vs price](images/cancer_02.png)
#
#  ¿cómo podemos predecir si el tumor de este paciente es benigno o maligno? Bueno, dado que el día se dice así, lo que el algoritmo de aprendizaje podría hacer es encontrar algún límite que separe los tumores malignos de los benignos. Por lo tanto, el algoritmo de aprendizaje tiene que decidir cómo trazar una línea límite a través de estos datos.
#
#  ![size vs price](images/cance_03.png)
#
#   En este caso, es más probable que el tumor sea benigno.
#
#
#
#   ### Conclusión
#
#   Para resumir, el aprendizaje supervisado mapea la entrada x con la salida y, donde el algoritmo de aprendizaje aprende de las respuestas correctas entre comillas. Los dos tipos principales de aprendizaje supervisado son la regresión y la clasificación. En una aplicación de regresión como la de predicción de precios de casas, el algoritmo de aprendizaje tiene que predecir números a partir de un número infinito de números de salida posibles. Mientras que en la clasificación, el algoritmo de aprendizaje tiene que hacer una predicción de una categoría, es decir, de un pequeño conjunto de resultados posibles.
#
#   ![size vs price](images/conclusión_01.png)

# %% [markdown]
# ## Unsupervised Learning
#
# En el aprendizaje no supervisado, cada ejemplo se asoció con una etiqueta de salida, como benigno o maligno, designada por los polos y cruces. Si recibimos datos que no están asociados a ninguna etiqueta de salida y, supongamos que se proporcionan datos sobre los pacientes y el tamaño de sus tumores y la edad de los pacientes. Pero no se sabe si el tumor era benigno o maligno, por lo que el conjunto de datos tiene el siguiente aspecto que se muestra a la derecha
#
# ![size vs price](images/unsupervised_01.png)
#
# No se nos pide que diagnostiquemos si el tumor es benigno o maligno porque no se nos indica ninguna etiqueta. Por eso, en el conjunto de datos, nuestro trabajo consiste en encontrar alguna estructura o patrón o simplemente encontrar algo interesante en los datos. Esto es aprendizaje no supervisado, lo llamamos no supervisado porque no estamos intentando supervisar el algoritmo.
#
#
# Un algoritmo de aprendizaje no supervisado podría decidir que los datos se pueden asignar a dos grupos diferentes o a dos clústeres diferentes. Por lo tanto, podría decidir que hay un grupo por aquí y hay otro grupo o grupo por aquí. Este es un tipo particular de aprendizaje no supervisado, llamado algoritmo de agrupamiento.
#
# ![size vs price](images/clustering.png)
#
# #### Primer ejemplo
#
# Por ejemplo, la agrupación en clústeres se usa en Google News, lo que hace Google News es cada día que pasa. También analiza cientos de miles de artículos de noticias en Internet y agrupa artículos relacionados.
#
# ![size vs price](images/clustering_01.png)
#
# Tal vez solo con los titulares, puedas empezar a adivinar lo que podría estar haciendo la agrupación en clústeres. Observe que la palabra panda aparece aquí, aquí, aquí y aquí y observe que la palabra gemelo también aparece en los cinco artículos. Y la palabra Zoo también aparece en todos estos artículos, por lo que el algoritmo de agrupamiento consiste en buscar artículos. Todos los cientos de miles de artículos de noticias que aparecieron en Internet ese día, buscar los artículos que mencionen palabras similares y agruparlos en grupos. Ahora, lo que mola es que este algoritmo de agrupamiento descubre por sí mismo qué palabras sugieren que ciertos artículos pertenecen al mismo grupo. Lo que quiero decir es que no hay ningún empleado de Google News que le diga al algoritmo que busque artículos en los que aparezca la palabra panda.
#
# los temas de las noticias cambian todos los días. Y hay tantas noticias que no es posible que la gente haga esto todos los días para todos los temas que aparecen en las portadas. En cambio, el algoritmo tiene que averiguar por sí mismo, sin supervisión, cuáles son los grupos de artículos de noticias actuales. Por eso este algoritmo de agrupamiento es un tipo de algoritmo de aprendizaje no supervisado.
#
#
# #### Segundo ejemplo
#
#  Veamos el segundo ejemplo de aprendizaje no supervisado aplicado a la agrupación de datos genéticos o de ADN. Esta imagen muestra una imagen de datos de microarrays de ADN, que parecen cuadrículas diminutas de una hoja de cálculo. Y cada columna diminuta representa la actividad genética o del ADN de una persona.
#
# ![size vs price](images/adn.png)
#
#
# Por ejemplo, toda esta columna proviene del ADN de una persona. Y esta otra columna es de otra persona, cada fila representa un gen en particular. A modo de ejemplo, tal vez este papel podría representar un gen que afecta el color de los ojos, o este papel es un gen que afecta la estatura de una persona. Los investigadores incluso han descubierto una relación genética con el hecho de que a una persona no le gusten ciertos vegetales, como el brócoli, las coles de Bruselas o los espárragos. Así que la próxima vez que alguien te pregunte por qué no te acabaste la ensalada, puedes decirle que tal vez se deba a la genética de una microraza de ADN. La idea es medir en qué medida se expresan ciertos genes en cada persona individual. Por lo tanto, estos colores rojo, verde, gris, etc., muestran el grado en que diferentes individuos tienen o no un gen específico activo.
#
# ![size vs price](images/adn_01.png)
#
#  A continuación, lo que puede hacer es ejecutar un algoritmo de agrupamiento para agrupar a las personas en diferentes categorías. O diferentes tipos de personas, tal vez como estas personas que se agrupan, y llamemos simplemente a este tipo de personas. Y estas personas se agrupan en el tipo dos, y estas personas son grupos del tipo tres.
#
#
# ![size vs price](images/adn_02.png)
#
# Se trata de un aprendizaje no supervisado, porque no le explicamos al algoritmo de antemano que hay una persona del tipo uno con ciertas características. O una persona del tipo dos con ciertas características; en cambio, lo que estamos diciendo es que aquí hay un montón de datos. No sé cuáles son los diferentes tipos de personas, pero ¿se puede encontrar automáticamente la estructura de los datos? Y averigüe automáticamente cuáles son los tipos principales de personas, ya que no le estamos dando al algoritmo la respuesta correcta para los ejemplos de antemano.
#
#
# #### Tercer ejemplo
#
# Este es el tercer ejemplo. Muchas empresas tienen enormes bases de datos con información de clientes a partir de estos datos.
#
# ¿Puede agrupar automáticamente a sus clientes en diferentes segmentos de mercado para poder atenderlos de manera más eficiente?
#
# Concretamente, el equipo de Deep Learning Dot AI investigó un poco para entender mejor a la comunidad de Deep Learning Dot AI. Y por qué diferentes personas asisten a estas clases, se suscriben al boletín semanal de Batch o asisten a nuestros eventos de IA.
#
#  Visualicemos la comunidad de IA basada en puntos de aprendizaje profundo, como un conjunto de personas que gestionan la creación de clústeres. Es decir, la segmentación del mercado encontró unos pocos grupos distintos de personas. La principal motivación de un grupo es la búsqueda de conocimientos para desarrollar sus habilidades. La principal motivación de un segundo grupo es buscar una forma de desarrollar su carrera. Tal vez quieras conseguir un ascenso o un nuevo trabajo, o progresar en tu carrera, si esto te describe, eso también es genial. Y otro grupo quiere mantenerse al día sobre el impacto de la IA en su campo de trabajo.
#
#
# ![size vs price](images/customers.png)
#
# Este es un agrupamiento que nuestro equipo utilizó para tratar de ofrecer un mejor servicio a nuestra comunidad a medida que intentábamos averiguar.
#
# resumiendo un algoritmo de agrupamiento. Es un tipo de algoritmo de aprendizaje no supervisado, que toma datos sin etiquetas e intenta agruparlos automáticamente en grupos.
#
# Además de la agrupación en clústeres, también existen otros tipos de aprendizaje no supervisado.

# %% [markdown]
# ### Otros algoritmos unsupervised
#
# Mientras que en el aprendizaje supervisado, los datos vienen con las entradas x y con las etiquetas de entrada y, en el aprendizaje no supervisado, los datos vienen solo con las entradas x, pero no con las etiquetas de salida y, y el algoritmo tiene que encontrar alguna estructura, patrón o algo interesante en los datos.
#
#
#  En esta especialización, aprenderás sobre la agrupación en clústeres y sobre otros dos tipos de aprendizaje no supervisado. Una de ellas se llama detección de anomalías y se usa para detectar eventos inusuales. Esto resulta muy importante para la detección de fraudes en el sistema financiero, donde eventos y transacciones inusuales pueden ser señales de fraude, y para muchas otras aplicaciones. También aprenderás sobre la reducción de la dimensionalidad. Esto le permite tomar un gran conjunto de datos y comprimirlo casi por arte de magia para convertirlo en un conjunto de datos mucho más pequeño y, al mismo tiempo, perder la menor cantidad de información posible.
#
#
# ![size vs price](images/unsupervised_03.png)

# %% [markdown]
# # proceso general del aprendizaje supervisado
#
#
#
# ### Modelo de regresión lineal.
#
# Comencemos con un problema que puede abordar mediante la regresión lineal. Supongamos que quiere predecir el precio de una casa en función del tamaño de la casa. Este es el ejemplo que vimos a principios de esta semana. Vamos a usar un conjunto de datos sobre el tamaño y los precios de las casas en Portland, una ciudad de los Estados Unidos. Aquí tenemos un gráfico donde el eje horizontal es el tamaño de la casa en pies cuadrados y el eje vertical es el precio de una casa en miles de dólares. Sigamos y grafiquemos los puntos de datos de varias casas del conjunto de datos. Aquí, cada punto de datos, cada una de estas pequeñas cruces, es una casa con el tamaño y el precio por los que se vendió recientemente.
#
# ![size vs price](images/regresion_01.png)
#
# Ahora, supongamos que eres un agente inmobiliario en Portland y estás ayudando a una clienta a vender su casa. Te pregunta cuánto crees que me pueden dar por esta casa. Este conjunto de datos podría ayudarlo a estimar el precio que podría obtener por ella. Empiezas midiendo el tamaño de la casa y resulta que la casa tiene 1250 pies cuadrados. ¿ Por cuánto crees que se podría vender esta casa? Una cosa que podrías hacer es crear un modelo de regresión lineal a partir de este conjunto de datos. Su modelo ajustará una línea recta a los datos, que podrían tener este aspecto. Basándose en esta línea recta ajustada a los datos, puede ver que la casa tiene 1250 pies cuadrados, se cruzará con la línea que mejor se ajuste aquí y, si la traza hasta el eje vertical de la izquierda, puede ver que el precio puede estar por aquí, digamos unos 220 000$. Este es un ejemplo de lo que se denomina modelo de aprendizaje supervisado. A esto lo llamamos aprendizaje supervisado porque primero se entrena un modelo proporcionando un dato con las respuestas correctas

# %% [markdown]
#  Cualquier modelo de aprendizaje supervisado que prediga un número como 220.000 o 1,5 o menos 33,2 aborda lo que se denomina un problema de regresión. La regresión lineal es un ejemplo de modelo de regresión. Pero también hay otros modelos para abordar los problemas de regresión.

# %% [markdown]
# hay otra forma de ver los datos que sería útil, y es una tabla de datos aquí a la derecha.
#
# ![size vs price](images/regresion_02.png)
#
# El conjunto de datos que acabas de ver y que se usa para entrenar el modelo se denomina conjunto de entrenamiento. Tenga en cuenta que la casa de su cliente no está en este conjunto de datos porque aún no se ha vendido, por lo que nadie sabe cuál es el precio. Para predecir el precio de la casa de tu cliente, primero debes entrenar tu modelo para que aprenda del conjunto de entrenamiento y, a continuación, ese modelo podrá predecir el precio de la casa de tu cliente.
#
#  Esto no es x elevado a 2. Solo se refiere al segundo ejemplo de entrenamiento. Esto es solo un índice del conjunto de entrenamiento y hace referencia a la fila i de la tabla.
#
# ![size vs price](images/regresion_03.png)

# %% [markdown]
# ### Regresión Lineal con una variable
#
#
#  Recuerde que un conjunto de entrenamiento de aprendizaje supervisado incluye tanto las características de entrada, como el tamaño de la casa, como los objetivos de rendimiento, como el precio de la casa. Los objetivos de producción son las respuestas correctas al modelo del que aprenderemos. Para entrenar el modelo, incorporas al conjunto de entrenamiento, tanto las características de entrada como los objetivos de salida, a tu algoritmo de aprendizaje. Luego, tu algoritmo de aprendizaje supervisado producirá alguna función. Escribiremos esta función como f minúscula, donde f significa función. Históricamente, esta función solía llamarse hipótesis, pero en esta clase simplemente la llamaré función f.
#
#   El trabajo con f consiste en tomar una nueva entrada x y una salida y estimar o hacer una predicción, que llamaré y-hat, y se escribe como la variable y con el símbolo de este sombrerito en la parte superior. En el aprendizaje automático, la convención es que y-hat es la estimación o la predicción de y. La función f se denomina modelo.
#
# ![size vs price](images/regresion_04.png)
#
#  X se denomina entrada o entidad de entrada, y la salida del modelo es la predicción, y-hat. La predicción del modelo es el valor estimado de y.
#
#
# Si el símbolo es solo la letra y, se refiere al objetivo, que es el valor real real del conjunto de entrenamiento. En cambio, y-hat es una estimación. Puede o no ser el valor real real.
#
# Su modelo f, dado el tamaño, arroja el precio, que es el estimador, es decir, la predicción de cuál será el precio real. Ahora, cuando diseñamos un algoritmo de aprendizaje, una pregunta clave es, ¿cómo vamos a representar la función f? O dicho de otro modo, ¿cuál es la fórmula matemática que vamos a usar para calcular f?
#
#
# Tu función se puede escribir como $f_{w,b}$ es igual a, voy a usar w multiplicado por x más b. Definiré w y b pronto. Pero por ahora, basta con saber que w y b son números, y los valores elegidos para w y b determinarán la predicción y-hat en función de la entidad de entrada x.
#
# ![size vs price](images/regresion_05.png)
#
# Esta $f_{w,b}$ significa que f es una función que toma x como entrada y, según los valores de w y b
#
# Para que esto funcione, una de las cosas más importantes que tiene que hacer es construir una función de costo. La idea de una función de costes es una de las ideas más universales e importantes del aprendizaje automático, y se utiliza tanto en la regresión lineal como en el entrenamiento de muchos de los modelos de IA más avanzados del mundo.

# %% [markdown]
# ## Laboratorio

# %% [markdown]
# ## Goals
# In this lab you will:
# - Learn to implement the model $f_{w,b}$ for linear regression with one variable

# %% [markdown]
# ## Notation
# Here is a summary of some of the notation you will encounter.
#
# ![size vs price](images/regresion_06.png)

# %% [markdown]
# ## Tools
# In this lab you will make use of:
# - NumPy, a popular library for scientific computing
# - Matplotlib, a popular library for plotting data

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# # Problem Statement
# <img align="left" src="./images/regresion_07.png"    style=" width:380px; padding: 10px;  " />
#
# As in the lecture, you will use the motivating example of housing price prediction.
# This lab will use a simple data set with only two data points - a house with 1000 square feet(sqft) sold for \\$300,000 and a house with 2000 square feet sold for \\$500,000. These two points will constitute our *data or training set*. In this lab, the units of size are 1000 sqft and the units of price are 1000s of dollars.
#
# | Size (1000 sqft)     | Price (1000s of dollars) |
# | -------------------| ------------------------ |
# | 1.0               | 300                      |
# | 2.0               | 500                      |
#
# You would like to fit a linear regression model (shown above as the blue straight line) through these two points, so you can then predict price for other houses - say, a house with 1200 sqft.

# %% [markdown]
# Please run the following code cell to create your x_train and y_train variables. The data is stored in one-dimensional NumPy arrays.

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %% [markdown]
# Número de ejemplos de entrenamiento m
# Se usará m para indicar el número de ejemplos de entrenamiento. Los arrays de NumPy tienen un parámetro .shape. x_train.shape devuelve una tupla de Python con una entrada para cada dimensión. x_train.shape[0] representa la longitud del array y el número de ejemplos, como se muestra a continuación.

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is: {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2

# %% [markdown]
# One can also use the Python `len()` function as shown below.

# %%
# m is the number of training examples
m = len(x_train)
print(f"Number of training examples is: {m}")
# Out:
# Number of training examples is: 2

# %% [markdown]
# Ejemplo de entrenamiento x_i, y_i
# Usarás (x (𝑖)
# , y (𝑖)
# ) para denotar el ejemplo de entrenamiento 𝑖𝑡ℎ. Dado que Python tiene indexación cero, (x (0)
# , y (0)
# ) es (1.0, 300.0) y (x (1)
# , y (1)
# ) es (2.0, 500.0).
#
# Para acceder a un valor en un array de Numpy, se indexa el array con el desplazamiento deseado. Por ejemplo, la sintaxis para acceder a la posición cero de x_train es x_train[0]. Ejecuta el siguiente bloque de código para obtener el ejemplo de entrenamiento 𝑖𝑡ℎ.

# %%
i = 0 # Change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %% [markdown]
# Trazando los datos
# Puedes trazar estos dos puntos usando la función scatter() de la biblioteca matplotlib, como se muestra en la celda a continuación.
#
# Los argumentos de la función "marker" y "c" muestran los puntos como cruces rojas (el valor predeterminado son puntos azules).
# Puedes usar otras funciones de la biblioteca matplotlib para configurar el título y las etiquetas que se mostrarán.

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %% [markdown]
# ## Model function
#
# <img align="left" src="./images/regresion_09.png"     style=" width:380px; padding: 10px; " > Como se describe en la lección, la función modelo para la regresión lineal (que es una función que se asigna de x a y) se representa como
#
# $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
#
# La fórmula anterior muestra cómo se pueden representar líneas rectas: diferentes valores de 𝑤 y 𝑏 dan como resultado diferentes líneas rectas en el gráfico.<br/> <br/> <br/> <br/> <br/>
#
# Intentemos comprender mejor esto con los bloques de código a continuación. Empecemos con $w = 100$ and $b = 100$.
#
# **Nota: Puede volver a esta celda para ajustar los parámetros w y b del modelo**

# %%
w = 100
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %% [markdown]
# Ahora, calculemos el valor de $f_{w,b}(x^{(i)})$ Para tus dos puntos de datos. Puedes escribir esto explícitamente para cada punto de datos como:
#
# for $x^{(0)}$, `f_wb = w * x[0] + b`
#
# for $x^{(1)}$, `f_wb = w * x[1] + b`
#
# Para una gran cantidad de puntos de datos, esto puede resultar complicado y repetitivo. Por lo tanto, puede calcular la salida de la función en un `for` bucle como se muestra en la `compute_model_output` función a continuación.
#
# > **Note**: La descripción del argumento `(ndarray (m,))` describe una matriz n-dimensional Numpy de forma (m,). `(scalar)` describe un argumento sin dimensiones, solo una magnitud.
# > **Note**: `np.zero(n)` Devolverá una matriz numpy unidimensional con $n$ entradas

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      f_wb (ndarray (m,)): model prediction
    """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
        
    return f_wb

# %% [markdown]
# Ahora llamemos a la función compute_model_output y grafiquemos la salida.

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %% [markdown]
# Como puedes ver, establecer $w = 100$ y $b = 100$ *no* da como resultado una línea que se ajuste a nuestros datos.
#
# ### Desafío
# Intenta experimentar con diferentes valores de $w$ y $b$. ¿Cuáles deberían ser los valores para una línea que se ajuste a nuestros datos?
#
# #### Consejo:
# Puedes usar el ratón para hacer clic en las "Pistas" verdes a continuación para ver algunas sugerencias para elegir b y w.

# %% [markdown]
# <details>
# <summary>
#     <font size='3', color='darkgreen'><b>Hints</b></font>
# </summary>
#     <p>
#     <ul>
#         <li>Try $w = 200$ and $b = 100$ </li>
#     </ul>
#     </p>

# %% [markdown]
# ### Prediction
# Ahora que tenemos un modelo, podemos usarlo para hacer nuestra predicción original. Predigamos el precio de una casa de 1200 pies cuadrados. Como las unidades de $x$ están en miles de pies cuadrados, $x$ es 1,2.

# %%
w = 200                         
b = 100    
x_i = 1.2
cost_1200sqft = w * x_i + b    

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars

# %% [markdown]
# # Congratulations!
# En este laboratorio has aprendido:
#  - La regresión lineal construye un modelo que establece una relación entre características y objetivos.
#      - En el ejemplo anterior, la característica era el tamaño de la casa y el objetivo era el precio de la casa.
#      - Para la regresión lineal simple, el modelo tiene dos parámetros $w$ y $b$ cuyos valores se 'ajustan' utilizando *datos de entrenamiento*.
#      - Una vez que se han determinado los parámetros de un modelo, éste puede utilizarse para hacer predicciones sobre datos nuevos.

# %% [markdown]
# ## Formula de la función de costo
#
# Para implementar la regresión lineal, el primer paso clave es primero definir algo llamado función de costo. la función de coste nos dirá qué tan bien funciona el modelo para que podamos intentar mejorarlo.

# %% [markdown]
# ![size vs price](images/regresion_08.png)
#
#  Recuerde que tiene un conjunto de entrenamiento que contiene las características de entrada x y los objetivos de salida y.
#
#  El modelo que utilizará para ajustar este conjunto de entrenamiento es la función lineal f_w, b de x es igual a w multiplicado por x más b. Para introducir un poco más de terminología, w y b se denominan parámetros del modelo.
#
#   Para introducir un poco más de terminología, w y b se denominan parámetros del modelo.
#
#   En el aprendizaje automático, los parámetros del modelo son las variables que se pueden ajustar durante el entrenamiento para mejorar el modelo.

# %% [markdown]
# Cuando w es igual a 0 y b es igual a 1.5, entonces f se parece a esta línea horizontal.
#
# ![size vs price](images/regresion_10.png)
#
# En este caso, la función f de x es 0 multiplicado por x más 1,5, por lo que f siempre es un valor constante. Siempre predice 1.5 para el valor estimado de y.
#
# Y es siempre igual a b y, en este caso, b también recibe el nombre de intersección con el eje y porque es donde cruza el eje vertical o el eje y de esta gráfica.
#
# Como segundo ejemplo, si w es 0.5 y b es igual a 0, entonces f de x es 0.5 veces x. Cuando x es 0, la predicción también es 0, y cuando x es 2, entonces la predicción es 0.5 veces 2, que es 1. Obtienes una recta con este aspecto y observas que la pendiente es 0.5 dividido por 1. El valor de w te da la pendiente de la recta, que es 0.5.
#
# ![size vs price](images/regresion_11.png)
#
# Finalmente, si w es igual a 0.5 y b es igual a 1, entonces f de x es 0.5 veces x más 1 y cuando x es 0, entonces f de x es igual a b, que es 1, por lo que la recta se cruza con el eje vertical en b, la intersección con y. Además, cuando x es 2, entonces f de x es 2, por lo que la línea tiene este aspecto. De nuevo, esta pendiente es 0.5 dividida por 1, así que el valor de w da como resultado la pendiente que es 0.5.
#
# ![size vs price](images/regresion_12.png)
#
# Recuerda que tienes un conjunto de entrenamiento como el que se muestra aquí. Con la regresión lineal, lo que se quiere hacer es elegir valores para los parámetros w y b de manera que la línea recta que se obtiene de la función f se ajuste de alguna manera a los datos.
#
#  Ahora la pregunta es cómo se encuentran los valores para w y b de modo que la predicción y que i esté cerca del verdadero objetivo y^i para muchos o quizás todos los ejemplos de entrenamiento x^i ^i, y^i.
#
#  ![size vs price](images/regresion_13.png)
#
#  Para responder a esa pregunta, veamos primero cómo medir qué tan bien se ajusta una línea a los datos de entrenamiento. Para ello, vamos a construir una función de coste. La función de costo toma la predicción y hat y la compara con el objetivo y, tomando y eso menos y.
#
#   Esta diferencia se denomina error, estamos midiendo qué tan lejos está la predicción del objetivo.
#
#
#   Para crear una función de coste que no aumente automáticamente a medida que aumenta el tamaño del conjunto de entrenamiento, calcularemos el error cuadrático medio en lugar del error cuadrático total y lo haremos dividiendo por m de la siguiente manera. Ya casi estamos allí. Solo una última cosa. Por convención, la función de coste que utilizan los profesionales del aprendizaje automático divide entre 2 por m. La división adicional por 2 solo sirve para hacer que algunos de nuestros cálculos posteriores parezcan más precisos, pero la función de coste sigue funcionando tanto si incluyes esta división por 2 como si no.
#
#   Esta expresión de aquí es la función de costo y vamos a escribir J de wb para referirnos a la función de costo.
#
# ![size vs price](images/regresion_15.png)
#
#
#  También se llama función de coste del error al cuadrado, y se llama así porque se calcula el cuadrado de estos términos de error. En el aprendizaje automático, diferentes personas utilizan diferentes funciones de coste para distintas aplicaciones, pero la función de coste del error cuadrático es, con diferencia, la más utilizada para la regresión lineal y, de hecho, para todos los problemas de regresión en los que parece dar buenos resultados en muchas aplicaciones.

# %% [markdown]
# ## Intuición de la función de costes
#
#  Si desea ajustar una línea recta a los datos de entrenamiento, tiene este modelo, $$ f_{w,b}(x) = wx + b$$
#
#  Aquí, los parámetros del modelo son w y b. Ahora, dependiendo de los valores elegidos para estos parámetros, se obtienen diferentes líneas rectas como esta.
#
#  Quieres encontrar los valores de w y b, de forma que la línea recta se ajuste bien a los datos de entrenamiento.
#
#  Para medir qué tan bien una selección de w y b se ajusta a los datos de entrenamiento, tiene una función de costo J.
#
#  ![size vs price](images/regresion_16.png)
#
#   Lo que hace la función de costo J es medir la diferencia entre las predicciones del modelo y los valores reales reales de y. Lo que verá más adelante es que la regresión lineal trataría de encontrar valores para w y b, y luego hacer que una J de w sea lo más pequeña posible.
#
#   ![size vs price](images/regresion_17.png)
#
#
#   El objetivo de la regresión lineal es encontrar los parámetros w y b que dan como resultado el menor valor posible para la función de coste J.

# %% [markdown]
# ## Visualización de la función de costes J
#
# Tenemos el modelo, los parámetros w y b del modelo, la función de coste J de w y b, así como el objetivo de la regresión lineal, que consiste en minimizar la función de coste J de w y b con respecto a los parámetros w y b.
#
# Aquí, he establecido w en 0.06 y b en 50.
#
#  ![size vs price](images/regresion_18.png)
#
#  Tenga en cuenta que este no es un modelo particularmente bueno para este conjunto de entrenamiento, en realidad es un modelo bastante malo.
#
#
#  Ahora, en este ejemplo del precio de la vivienda que tenemos en esta diapositiva, tenemos dos parámetros, w y b. Las parcelas se vuelven un poco más complejas. Resulta que la función de coste también tiene una forma similar a la de un tazón de sopa, excepto en tres dimensiones en lugar de dos.
#
#  ![size vs price](images/regresion_19.png)
#
#   Lo que ve aquí es un gráfico de superficie 3D en el que los ejes se etiquetan como w y b. Al variar w y b, que son los dos parámetros del modelo, se obtienen valores diferentes para la función de coste J de w y b.
#
#   Al final de esta diapositiva hay una gráfica de superficie en 3D de la función de coste J. Sé que no tiene mucha forma de cuenco, pero en realidad es un cuenco muy estirado, por eso tiene ese aspecto.
#
#  ![size vs price](images/regresion_20.png)

# %% [markdown]
# # Optional  Lab: Cost Function
# <figure>
#     <center> <img src="./images/C1_W1_L3_S2_Lecture_b.png"  style="width:1000px;height:200px;" ></center>
# </figure>

# %% [markdown]
# ## Goals
# In this lab you will:
# - you will implement and explore the `cost` function for linear regression with one variable.

# %% [markdown]
# ## Tools
# In this lab we will make use of:
# - NumPy, a popular library for scientific computing
# - Matplotlib, a popular library for plotting data
# - local plotting routines in the lab_utils_uni.py file in the local directory

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# ## Problem Statement
#
# You would like a model which can predict housing prices given the size of the house.
# Let's use the same two data points as before the previous lab- a house with 1000 square feet sold for \\$300,000 and a house with 2000 square feet sold for \\$500,000.
#
#
# | Size (1000 sqft)     | Price (1000s of dollars) |
# | -------------------| ------------------------ |
# | 1                 | 300                      |
# | 2                  | 500                      |

# %%
x_train = np.array([1.0, 2.0])           #(size in 1000 square feet)
y_train = np.array([300.0, 500.0])           #(price in 1000s of dollars)

# %% [markdown]
# ## Computing Cost
# The term 'cost' in this assignment might be a little confusing since the data is housing cost. Here, cost is a measure how well our model is predicting the target price of the house. The term 'price' is used for housing data.
#
# The equation for cost with one variable is:
#   $$J(w,b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})^2 \tag{1}$$
#
# where
#   $$f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{2}$$
#
# - $f_{w,b}(x^{(i)})$ is our prediction for example $i$ using parameters $w,b$.
# - $(f_{w,b}(x^{(i)}) -y^{(i)})^2$ is the squared difference between the target value and the prediction.
# - These differences are summed over all the $m$ examples and divided by `2m` to produce the cost, $J(w,b)$.
# >Note, in lecture summation ranges are typically from 1 to m, while code will be from 0 to m-1.

# %% [markdown]
# The code below calculates cost by looping over each example. In each loop:
# - `f_wb`, a prediction is calculated
# - the difference between the target and the prediction is calculated and squared.
# - this is added to the total cost.

# %%
def compute_cost(x, y, w, b): 
    """
    Computes the cost function for linear regression.
    
    Args:
      x (ndarray (m,)): Data, m examples 
      y (ndarray (m,)): target values
      w,b (scalar)    : model parameters  
    
    Returns
        total_cost (float): The cost of using w,b as the parameters for linear regression
               to fit the data points in x and y
    """
    # number of training examples
    m = x.shape[0] 
    
    cost_sum = 0 
    for i in range(m): 
        f_wb = w * x[i] + b   
        cost = (f_wb - y[i]) ** 2  
        cost_sum = cost_sum + cost  
    total_cost = (1 / (2 * m)) * cost_sum  

    return total_cost

# %% [markdown]
# ## Cost Function Intuition

# %% [markdown]
# <img align="left" src="./images/C1_W1_Lab02_GoalOfRegression.PNG"    style=" width:380px; padding: 10px;  " /> Your goal is to find a model $f_{w,b}(x) = wx + b$, with parameters $w,b$,  which will accurately predict house values given an input $x$. The cost is a measure of how accurate the model is on the training data.
#
# The cost equation (1) above shows that if $w$ and $b$ can be selected such that the predictions $f_{w,b}(x)$ match the target data $y$, the $(f_{w,b}(x^{(i)}) - y^{(i)})^2 $ term will be zero and the cost minimized. In this simple two point example, you can achieve this!
#
# In the previous lab, you determined that $b=100$ provided an optimal solution so let's set $b$ to 100 and focus on $w$.
#
# <br/>
# Below, use the slider control to select the value of $w$ that minimizes cost. It can take a few seconds for the plot to update.

# %%
plt_intuition(x_train,y_train)
# Out:
# interactive(children=(IntSlider(value=150, description='w', max=400, step=10), Output()), _dom_classes=('widge…

# %% [markdown]
# The plot contains a few points that are worth mentioning.
# - cost is minimized when $w = 200$, which matches results from the previous lab
# - Because the difference between the target and pediction is squared in the cost equation, the cost increases rapidly when $w$ is either too large or too small.
# - Using the `w` and `b` selected by minimizing cost results in a line which is a perfect fit to the data.

# %% [markdown]
# ## Cost Function Visualization- 3D
#
# You can see how cost varies with respect to *both* `w` and `b` by plotting in 3D or using a contour plot.
# It is worth noting that some of the plotting in this course can become quite involved. The plotting routines are provided and while it can be instructive to read through the code to become familiar with the methods, it is not needed to complete the course successfully. The routines are in lab_utils_uni.py in the local directory.

# %% [markdown]
# ### Larger Data Set
# It is instructive to view a scenario with a few more data points. This data set includes data points that do not fall on the same line. What does that mean for the cost equation? Can we find $w$, and $b$ that will give us a cost of 0?

# %%
x_train = np.array([1.0, 1.7, 2.0, 2.5, 3.0, 3.2])
y_train = np.array([250, 300, 480,  430,   630, 730,])

# %% [markdown]
# In the contour plot, click on a point to select `w` and `b` to achieve the lowest cost. Use the contours to guide your selections. Note, it can take a few seconds to update the graph.

# %%
plt.close('all') 
fig, ax, dyn_items = plt_stationary(x_train, y_train)
updater = plt_update_onclick(fig, ax, x_train, y_train, dyn_items)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Above, note the dashed lines in the left plot. These represent the portion of the cost contributed by each example in your training set. In this case, values of approximately $w=209$ and $b=2.4$ provide low cost. Note that, because our training examples are not on a line, the minimum cost is not zero.

# %% [markdown]
# ### Convex Cost surface
# The fact that the cost function squares the loss ensures that the 'error surface' is convex like a soup bowl. It will always have a minimum that can be reached by following the gradient in all dimensions. In the previous plot, because the $w$ and $b$ dimensions scale differently, this is not easy to recognize. The following plot, where $w$ and $b$ are symmetric, was shown in lecture:

# %%
soup_bowl()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Congratulations!
# You have learned the following:
#  - The cost equation provides a measure of how well your predictions match your training data.
#  - Minimizing the cost can provide optimal values of $w$, $b$.

# %% [markdown]
# ## Descenso del Gradiente

# %% [markdown]
# Sería bueno si tuviéramos una forma más sistemática de encontrar los valores de w y b, que diera como resultado el menor costo posible, j de w, b. Resulta que hay un algoritmo llamado gradiente descendente que se puede usar para hacer eso.

# %% [markdown]
# El gradiente descendente se utiliza de forma generalizada en el aprendizaje automático, no solo para la regresión lineal, sino también para entrenar, por ejemplo, algunos de los modelos de redes neuronales más avanzados, también denominados modelos de aprendizaje profundo. Los modelos de aprendizaje profundo son algo que aprendiste en el segundo curso. Si aprendes estos dos tipos de gradiente descendiente, dispondrás de uno de los pilares más importantes del aprendizaje automático.

# %% [markdown]
#  Para que esta discusión sobre el gradiente descendente sea más general, resulta que el gradiente descendente se aplica a funciones más generales, incluidas otras funciones de costo que funcionan con modelos que tienen más de dos parámetros. Por ejemplo, si tiene una función de costo J como función de w_1, w_2 hasta w_n y b, su objetivo es minimizar j sobre los parámetros w_1 a w_n y b. En otras palabras, desea seleccionar valores para w_1 a w_n y b, de modo que obtenga el menor valor posible de j.

# %% [markdown]
# Una cosa que debo tener en cuenta es que para algunas funciones j que pueden no tener forma de arco o de hamaca, es posible que haya más de un mínimo posible. Veamos un ejemplo de una gráfica de superficie j más compleja para ver qué efecto tiene el gradiente.
#
# ![size vs price](images/desenso_gradiente.png)

# %% [markdown]
# . Ahora imagina que vuelves a intentar el descenso por gradiente, pero esta vez eliges un punto de partida diferente seleccionando parámetros que sitúan tu punto de partida solo un par de pasos a la derecha. Si luego repites el proceso de descenso por gradiente , es decir, miras a tu alrededor, da un pequeño paso en la dirección de la pendiente más pronunciada para terminar aquí. Luego vuelves a mirar a tu alrededor, das otro paso, y así sucesivamente. Si tuvieras que correr en pendiente por segunda vez, comenzando solo un par de pasos a la derecha de donde lo hicimos la primera vez, terminarías en un valle totalmente diferente. Este mínimo diferente está aquí a la derecha. Los fondos del primer y del segundo valle se denominan mínimos locales.

# %% [markdown]
# ## Implementar descenso de gradiente

# %% [markdown]
# ![size vs price](images/descenso_gradiente.png)
#
#  Aquí está. En cada paso, w, el parámetro, se actualiza al valor anterior de w menos Alpha multiplicado por este término d/dw de la función cos J de wb. Lo que esta expresión quiere decir es que, después del parámetro w, se toma el valor actual de w y se ajusta una cantidad pequeña, que es la expresión de la derecha, menos Alfa multiplicado por este término.
#
#
#   En esta ecuación, Alpha también se denomina tasa de aprendizaje. La tasa de aprendizaje suele ser un número positivo pequeño entre 0 y 1 y podría ser, digamos, 0.01.
#
#   Lo que hace Alpha es básicamente controlar qué tan grande es el paso que das cuesta abajo. Si Alpha es muy grande, eso corresponde a un procedimiento de descenso en pendiente muy agresivo en el que intentas dar grandes pasos cuesta abajo.

# %% [markdown]
# ![size vs price](images/descenso_gradiente1.png)
#
# Bueno, para el algoritmo de descenso de gradientes, vas a repetir estos dos pasos de actualización hasta que el algoritmo converja.
#
#
# Por convergencias, quiero decir que se llega al punto, en un mínimo local, en el que los parámetros w y b ya no cambian mucho con cada paso adicional que se da.
#
#
# ![size vs price](images/descenso_gradiente2.png)

# %% [markdown]
# ## Intuición del descenso del Gradiente
#
#
# ![size vs price](images/descenso_gradiente3.png)
#
# Este es el algoritmo de descenso de gradiente que viste en el vídeo anterior. Como recordatorio, esta variable, el símbolo griego Alfa, es la tasa de aprendizaje. La tasa de aprendizaje controla el tamaño del paso que se da al actualizar los parámetros del modelo, w y b.

# %% [markdown]
# ![size vs price](images/descenso_gradiente4.png)
#
#  Por ejemplo, si dibujas un triángulo, la altura como esta es menos 2 y el ancho es 1, la pendiente es menos 2 dividido por 1, que es menos 2, que es un número negativo. Cuando actualizas w, obtienes w menos la tasa de aprendizaje multiplicado por un número negativo. Esto significa que restas a w, un número negativo. Sin embargo, restar un número negativo significa sumar un número positivo y, por lo tanto, se termina aumentando w. Porque restar un número negativo es lo mismo que sumar un número positivo a w. Este paso del descenso del gradiente hace que w aumente, lo que significa que te mueves hacia la derecha de la gráfica y tu costo J se reduce hasta aquí.

# %% [markdown]
# ## Tasa de Aprendizaje α

# %% [markdown]
# La elección de la tasa de aprendizaje, alfa, tendrá un gran impacto en la eficiencia de la implementación del gradiente de descenso. Y si es alfa, la tasa de aprendizaje se elige mal, la tasa de descenso puede que ni siquiera funcione.
#
# Para obtener más información sobre lo que hace la alfa de la tasa de aprendizaje. Veamos qué puede suceder si la tasa alfa de aprendizaje es demasiado pequeña o demasiado grande.

# %% [markdown]
#  Para el caso de que la tasa de aprendizaje sea demasiado pequeña.
#
#
# Esta es una gráfica donde el eje horizontal es W y el eje vertical es el costo J. Y esta es la gráfica de la función J de W. Comencemos a calificar el descenso en este punto, si la tasa de aprendizaje es demasiado pequeña. Entonces, lo que ocurre es que multiplicas el término de tu derivada por un número muy, muy pequeño. Así que vas a multiplicar por el número alfa. Eso es muy pequeño, como 0,0000001. Y así terminas dando un pequeño paso como ese. Luego, a partir de este punto, darás otro pequeño paso. Pero debido a que la tasa de aprendizaje es tan pequeña, el segundo paso también es minúsculo. El resultado de este proceso es que acabas reduciendo el coste J, pero de forma increíblemente lenta.
#
# ![size vs price](images/descenso_gradiente5.png)
#
# Resumiendo, si el ritmo de aprendizaje es demasiado pequeño, los descensos por pendiente funcionarán, pero serán lentos. Llevará mucho tiempo porque se van a dar pequeños pasos. Y van a necesitar muchos pasos antes de acercarse al mínimo.

# %% [markdown]
# Ahora, veamos un caso diferente. ¿Qué pasa si la tasa de aprendizaje es demasiado grande?
#
#
# Ahora, la derivada en este nuevo punto dice que hay que disminuir W pero cuando la tasa de aprendizaje es demasiado grande. Entonces puedes dar un gran paso yendo desde aquí hasta aquí. Así que ahora has llegado a este punto una y otra vez, si la tasa de aprendizaje es demasiado grande. Luego das otro gran paso con una aceleración y vuelves a sobrepasar con creces el mínimo. Así que ahora estás en este punto de la derecha y, una vez más, realizas otra actualización. Y terminas aquí y ahora estás en este punto. Como puede observar, en realidad se está alejando cada vez más del mínimo.
#
#
# ![size vs price](images/descenso_gradiente6.png)

# %% [markdown]
# He aquí otra pregunta, quizá se esté preguntando si alguno de sus parámetros W ya se encuentra en este punto.
# De modo que su costo J ya se encuentra en un mínimo local.
#
# ![size vs price](images/descenso_gradiente7.png)
#
#
# Ahora supongamos que después de varios escalones de descenso del gradiente, el parámetro W está aquí, digamos igual a cinco. Así que este es el valor actual de W. Esto significa que estás en este punto de la función de coste J.
#
# ![size vs price](images/descenso_gradiente8.png)
#
# Si damos un paso de actualización, tal vez nos lleve a ese punto. Y debido a que esta derivada es bastante grande, la gradación y el descenso dan un paso relativamente grande hacia la derecha. Ahora, estamos en este segundo punto en el que damos otro paso. Y te darás cuenta de que la pendiente no es tan pronunciada como en el primer punto. Así que la derivada no es tan grande. Por lo tanto, el siguiente paso de actualización no será tan grande como el primer paso. Ahora, lee este tercer punto aquí y la derivada es más pequeña que en el paso anterior. Y daremos un paso aún más pequeño a medida que nos acerquemos al mínimo. Lo decorativo se acerca cada vez más a cero. A medida que vayamos descendiendo por pendiente, iremos dando pequeños escalones hasta que finalmente lleguemos a un mínimo local. Para resumir, a medida que nos acerquemos a un gradiente mínimo local, el descenso tomará automáticamente pasos más pequeños. Y eso se debe a que a medida que nos acercamos al mínimo local, la derivada se hace automáticamente más pequeña. Y eso significa que los pasos de actualización también se reducen automáticamente. Incluso si la tasa alfa de aprendizaje se mantiene en algún valor fijo. Así que ese es el algoritmo de descenso de gradientes, puedes usarlo para intentar minimizar cualquier función de coste J.

# %% [markdown]
# ## Desenso gradual para la regresion lineal.

# %% [markdown]
# Anteriormente, analizaste el modelo de regresión lineal y, a continuación, la función de coste y, por último, el algoritmo de descenso de gradientes
#
# En este vídeo, vamos a trabajar juntos y utilizar la función de coste por error cuadrático para el modelo de regresión lineal con gradiente descendente. Esto nos permitirá entrenar el modelo de regresión lineal para que se ajuste a una línea recta y así obtener los datos de entrenamiento.
#
# ![size vs price](images/descenso_gradiente9.png)

# %% [markdown]
# A la derecha está la función de coste del error cuadrático. A continuación se muestra el algoritmo de descenso del gradiente. Resulta que si calculas estas derivadas, estos son los términos que obtendrías. La derivada con respecto a W es este 1 sobre m, la suma de i es igual a 1 a m. Luego, el término de error, que es la diferencia entre los valores predichos y los reales multiplicada por la entidad de entrada xi. La derivada con respecto a b es esta fórmula de aquí, que tiene el mismo aspecto que la ecuación anterior, excepto que no tiene el término xi al final.
#
# ![size vs price](images/descenso_gradiente10.png)

# %% [markdown]
# Calculo de la derivada (w)
#
# ![size vs price](images/descenso_gradiente11.png)

# %% [markdown]
# Calculo de la derivada (b)
#
# ![size vs price](images/descenso_gradiente12.png)

# %% [markdown]
# Ahora, vamos a familiarizarnos con el funcionamiento del gradiente de descenso. Una de las pautas que vimos con el gradiente de descenso es que puede llevar a un mínimo local en lugar de a un mínimo global. Si el mínimo global significa el punto que tiene el valor más bajo posible para la función de coste J de todos los puntos posibles.

# %% [markdown]
# Una de las pautas que vimos con el gradiente de descenso es que puede llevar a un mínimo local en lugar de a un mínimo global. Si el mínimo global significa el punto que tiene el valor más bajo posible para la función de coste J de todos los puntos posibles.
#
# Esta función tiene más de un mínimo local. Recuerde que, dependiendo de dónde inicialice los parámetros w y b, puede terminar en diferentes mínimos locales. Puedes terminar aquí, o puedes terminar aquí.
#
#
# ![size vs price](images/descenso_gradiente13.png)

# %% [markdown]
#  Pero resulta que cuando se utiliza una función de coste de error cuadrático con regresión lineal, la función de coste no tiene ni tendrá nunca varios mínimos locales. Tiene un mínimo global único debido a su forma de cuenco.
#
#  ![size vs price](images/descenso_gradiente14.png)
#
#  El término técnico para esto es que esta función de coste es una función convexa.
#
#  De manera informal, una función convexa tiene forma de cuenco y no puede tener ningún mínimo local que no sea el mínimo global único. Cuando implementas el gradiente descendente en una función convexa, una buena propiedad es que, siempre y cuando tu tasa de aprendizaje se elija de manera adecuada, siempre convergerá en el mínimo global.

# %% [markdown]
# ## Ejecución del Descenso del gradiente

# %% [markdown]
# Veamos qué sucede cuando ejecutas un gradiente de descenso para la regresión lineal. Vamos a ver el algoritmo en acción. Esta es una gráfica del modelo y los datos en la parte superior izquierda y una gráfica de contorno de la función de coste en la parte superior derecha y, en la parte inferior, la gráfica de superficie de la misma función de coste. A menudo, w y b se inicializan en 0, pero para esta demostración, inicialicemos w = -0.1 y b = 900. Así que esto corresponde a f (x) = -0.1x + 900.
#
# ![size vs price](images/descenso_gradiente15.png)

# %% [markdown]
# Ahora, si damos un paso usando el gradiente de descenso, terminamos yendo desde este punto de la función de coste que tenemos aquí hasta este punto justo hacia abajo y hacia la derecha, y observamos que el ajuste en línea recta también cambia un poco.
#
# Demos otro paso.
#
# La función de coste ha pasado ahora a este tercio y, de nuevo, la función f (x) también ha cambiado un poco.
#
# A medida que realices más de estos pasos, el coste irá disminuyendo en cada actualización. Por lo tanto, los parámetros w y b siguen esta trayectoria.
#
#
# ![size vs price](images/descenso_gradiente16.png)

# %% [markdown]
# Y si miras a la izquierda, obtienes este ajuste en línea recta correspondiente que se ajusta cada vez mejor a los datos hasta que alcancemos el mínimo global. El mínimo global corresponde a este ajuste en línea recta, que se ajusta relativamente bien a los datos. Quiero decir, ¿no es genial?
#
# ![size vs price](images/descenso_gradiente17.png)
#
#  Eso es un gradiente de descenso y lo usaremos para ajustar un modelo a los datos de retención. Y ahora puedes usar este modelo f (x) para predecir el precio de la casa de tus clientes o de la casa de cualquier otra persona.
#
#  Para ser más precisos, este proceso de descenso de gradiente se denomina descenso de gradiente por lotes.

# %% [markdown]
# El término descenso gradual se refiere al hecho de que, en cada paso del descenso de gradiente, vemos todos los ejemplos de entrenamiento, en lugar de solo un subconjunto de los datos de entrenamiento.

# %% [markdown]
# ## laboratorio final
#
# ### Goals
# In this lab, you will:
#
# automate the process of optimizing  𝑤
#   and  𝑏
#   using gradient descent.
#
#
# ### Tools
# In this lab, we will make use of:
#
# NumPy, a popular library for scientific computing
# Matplotlib, a popular library for plotting data
# plotting routines in the lab_utils.py file in the local directory

# %%
import math, copy
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')
from lab_utils_uni import plt_house_x, plt_contour_wgrad, plt_divergence, plt_gradients

# %% [markdown]
# <a name="toc_40291_2"></a>
# # Problem Statement
#
# Let's use the same two data points as before - a house with 1000 square feet sold for \\$300,000 and a house with 2000 square feet sold for \\$500,000.
#
# | Size (1000 sqft)     | Price (1000s of dollars) |
# | ----------------| ------------------------ |
# | 1               | 300                      |
# | 2               | 500                      |

# %%
# Load our data set
x_train = np.array([1.0, 2.0])   #features
y_train = np.array([300.0, 500.0])   #target value

# %% [markdown]
# <a name="toc_40291_2.0.1"></a>
# ### Compute_Cost
# This was developed in the last lab. We'll need it again here.

# %%
#Function to calculate the cost
def compute_cost(x, y, w, b):
   
    m = x.shape[0] 
    cost = 0
    
    for i in range(m):
        f_wb = w * x[i] + b
        cost = cost + (f_wb - y[i])**2
    total_cost = 1 / (2 * m) * cost

    return total_cost

# %% [markdown]
# <a name="toc_40291_2.1"></a>
# ## Gradient descent summary
# So far in this course, you have developed a linear model that predicts $f_{w,b}(x^{(i)})$:
# $$f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
# In linear regression, you utilize input training data to fit the parameters $w$,$b$ by minimizing a measure of the error between our predictions $f_{w,b}(x^{(i)})$ and the actual data $y^{(i)}$. The measure is called the $cost$, $J(w,b)$. In training you measure the cost over all of our training samples $x^{(i)},y^{(i)}$
# $$J(w,b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})^2\tag{2}$$

# %% [markdown]
# In lecture, *gradient descent* was described as:
#
# $$\begin{align*} \text{repeat}&\text{ until convergence:} \; \lbrace \newline
# \;  w &= w -  \alpha \frac{\partial J(w,b)}{\partial w} \tag{3}  \; \newline
#  b &= b -  \alpha \frac{\partial J(w,b)}{\partial b}  \newline \rbrace
# \end{align*}$$
# where, parameters $w$, $b$ are updated simultaneously.
# The gradient is defined as:
# $$
# \begin{align}
# \frac{\partial J(w,b)}{\partial w}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})x^{(i)} \tag{4}\\
#   \frac{\partial J(w,b)}{\partial b}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)}) \tag{5}\\
# \end{align}
# $$
#
# Here *simultaniously* means that you calculate the partial derivatives for all the parameters before updating any of the parameters.

# %% [markdown]
# <a name="toc_40291_2.2"></a>
# ## Implement Gradient Descent
# You will implement gradient descent algorithm for one feature. You will need three functions.
# - `compute_gradient` implementing equation (4) and (5) above
# - `compute_cost` implementing equation (2) above (code from previous lab)
# - `gradient_descent`, utilizing compute_gradient and compute_cost
#
# Conventions:
# - The naming of python variables containing partial derivatives follows this pattern,$\frac{\partial J(w,b)}{\partial b}$  will be `dj_db`.
# - w.r.t is With Respect To, as in partial derivative of $J(wb)$ With Respect To $b$.

# %% [markdown]
# <a name="toc_40291_2.3"></a>
# ### compute_gradient
# <a name='ex-01'></a>
# `compute_gradient`  implements (4) and (5) above and returns $\frac{\partial J(w,b)}{\partial w}$,$\frac{\partial J(w,b)}{\partial b}$. The embedded comments describe the operations.

# %%
def compute_gradient(x, y, w, b): 
    """
    Computes the gradient for linear regression 
    Args:
      x (ndarray (m,)): Data, m examples 
      y (ndarray (m,)): target values
      w,b (scalar)    : model parameters  
    Returns
      dj_dw (scalar): The gradient of the cost w.r.t. the parameters w
      dj_db (scalar): The gradient of the cost w.r.t. the parameter b     
     """
    
    # Number of training examples
    m = x.shape[0]    
    dj_dw = 0
    dj_db = 0
    
    for i in range(m):  
        f_wb = w * x[i] + b 
        dj_dw_i = (f_wb - y[i]) * x[i] 
        dj_db_i = f_wb - y[i] 
        dj_db += dj_db_i
        dj_dw += dj_dw_i 
    dj_dw = dj_dw / m 
    dj_db = dj_db / m 
        
    return dj_dw, dj_db

# %% [markdown]
# <img align="left" src="./images/C1_W1_Lab03_lecture_slopes.PNG"   style="width:340px;" > The lectures described how gradient descent utilizes the partial derivative of the cost with respect to a parameter at a point to update that parameter.
# Let's use our `compute_gradient` function to find and plot some partial derivatives of our cost function relative to one of the parameters, $w_0$.

# %%
plt_gradients(x_train,y_train, compute_cost, compute_gradient)
plt.show()

# %% [markdown]
# Above, the left plot shows $\frac{\partial J(w,b)}{\partial w}$ or the slope of the cost curve relative to $w$ at three points. On the right side of the plot, the derivative is positive, while on the left it is negative. Due to the 'bowl shape', the derivatives will always lead gradient descent toward the bottom where the gradient is zero.
#
# The left plot has fixed $b=100$. Gradient descent will utilize both $\frac{\partial J(w,b)}{\partial w}$ and $\frac{\partial J(w,b)}{\partial b}$ to update parameters. The 'quiver plot' on the right provides a means of viewing the gradient of both parameters. The arrow sizes reflect the magnitude of the gradient at that point. The direction and slope of the arrow reflects the ratio of $\frac{\partial J(w,b)}{\partial w}$ and $\frac{\partial J(w,b)}{\partial b}$ at that point.
# Note that the gradient points *away* from the minimum. Review equation (3) above. The scaled gradient is *subtracted* from the current value of $w$ or $b$. This moves the parameter in a direction that will reduce cost.

# %% [markdown]
# <a name="toc_40291_2.5"></a>
# ###  Gradient Descent
# Now that gradients can be computed,  gradient descent, described in equation (3) above can be implemented below in `gradient_descent`. The details of the implementation are described in the comments. Below, you will utilize this function to find optimal values of $w$ and $b$ on the training data.

# %%
def gradient_descent(x, y, w_in, b_in, alpha, num_iters, cost_function, gradient_function): 
    """
    Performs gradient descent to fit w,b. Updates w,b by taking 
    num_iters gradient steps with learning rate alpha
    
    Args:
      x (ndarray (m,))  : Data, m examples 
      y (ndarray (m,))  : target values
      w_in,b_in (scalar): initial values of model parameters  
      alpha (float):     Learning rate
      num_iters (int):   number of iterations to run gradient descent
      cost_function:     function to call to produce cost
      gradient_function: function to call to produce gradient
      
    Returns:
      w (scalar): Updated value of parameter after running gradient descent
      b (scalar): Updated value of parameter after running gradient descent
      J_history (List): History of cost values
      p_history (list): History of parameters [w,b] 
      """
    
    # An array to store cost J and w's at each iteration primarily for graphing later
    J_history = []
    p_history = []
    b = b_in
    w = w_in
    
    for i in range(num_iters):
        # Calculate the gradient and update the parameters using gradient_function
        dj_dw, dj_db = gradient_function(x, y, w , b)     

        # Update Parameters using equation (3) above
        b = b - alpha * dj_db                            
        w = w - alpha * dj_dw                            

        # Save cost J at each iteration
        if i<100000:      # prevent resource exhaustion 
            J_history.append( cost_function(x, y, w , b))
            p_history.append([w,b])
        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(num_iters/10) == 0:
            print(f"Iteration {i:4}: Cost {J_history[-1]:0.2e} ",
                  f"dj_dw: {dj_dw: 0.3e}, dj_db: {dj_db: 0.3e}  ",
                  f"w: {w: 0.3e}, b:{b: 0.5e}")
 
    return w, b, J_history, p_history #return w and J,w history for graphing

# %%
# initialize parameters
w_init = 0
b_init = 0
# some gradient descent settings
iterations = 10000
tmp_alpha = 1.0e-2
# run gradient descent
w_final, b_final, J_hist, p_hist = gradient_descent(x_train ,y_train, w_init, b_init, tmp_alpha, 
                                                    iterations, compute_cost, compute_gradient)
print(f"(w,b) found by gradient descent: ({w_final:8.4f},{b_final:8.4f})")
# Out:
# Iteration    0: Cost 7.93e+04  dj_dw: -6.500e+02, dj_db: -4.000e+02   w:  6.500e+00, b: 4.00000e+00
# Iteration 1000: Cost 3.41e+00  dj_dw: -3.712e-01, dj_db:  6.007e-01   w:  1.949e+02, b: 1.08228e+02
# Iteration 2000: Cost 7.93e-01  dj_dw: -1.789e-01, dj_db:  2.895e-01   w:  1.975e+02, b: 1.03966e+02
# Iteration 3000: Cost 1.84e-01  dj_dw: -8.625e-02, dj_db:  1.396e-01   w:  1.988e+02, b: 1.01912e+02
# Iteration 4000: Cost 4.28e-02  dj_dw: -4.158e-02, dj_db:  6.727e-02   w:  1.994e+02, b: 1.00922e+02
# Iteration 5000: Cost 9.95e-03  dj_dw: -2.004e-02, dj_db:  3.243e-02   w:  1.997e+02, b: 1.00444e+02
# Iteration 6000: Cost 2.31e-03  dj_dw: -9.660e-03, dj_db:  1.563e-02   w:  1.999e+02, b: 1.00214e+02
# Iteration 7000: Cost 5.37e-04  dj_dw: -4.657e-03, dj_db:  7.535e-03   w:  1.999e+02, b: 1.00103e+02
# Iteration 8000: Cost 1.25e-04  dj_dw: -2.245e-03, dj_db:  3.632e-03   w:  2.000e+02, b: 1.00050e+02
# ...

# %% [markdown]
# <img align="left" src="./images/C1_W1_Lab03_lecture_learningrate.PNG"  style="width:340px; padding: 15px; " >
# Take a moment and note some characteristics of the gradient descent process printed above.
#
# - The cost starts large and rapidly declines as described in the slide from the lecture.
# - The partial derivatives, `dj_dw`, and `dj_db` also get smaller, rapidly at first and then more slowly. As shown in the diagram from the lecture, as the process nears the 'bottom of the bowl' progress is slower due to the smaller value of the derivative at that point.
# - progress slows though the learning rate, alpha, remains fixed

# %% [markdown]
# ### Cost versus iterations of gradient descent
# A plot of cost versus iterations is a useful measure of progress in gradient descent. Cost should always decrease in successful runs. The change in cost is so rapid initially, it is useful to plot the initial decent on a different scale than the final descent. In the plots below, note the scale of cost on the axes and the iteration step.

# %%
# plot cost versus iteration  
fig, (ax1, ax2) = plt.subplots(1, 2, constrained_layout=True, figsize=(12,4))
ax1.plot(J_hist[:100])
ax2.plot(1000 + np.arange(len(J_hist[1000:])), J_hist[1000:])
ax1.set_title("Cost vs. iteration(start)");  ax2.set_title("Cost vs. iteration (end)")
ax1.set_ylabel('Cost')            ;  ax2.set_ylabel('Cost') 
ax1.set_xlabel('iteration step')  ;  ax2.set_xlabel('iteration step') 
plt.show()

# %% [markdown]
# Predictions
# Now that you have discovered the optimal values for the parameters  𝑤
#   and  𝑏
#  , you can now use the model to predict housing values based on our learned parameters. As expected, the predicted values are nearly the same as the training values for the same housing. Further, the value not in the prediction is in line with the expected value.

# %%
print(f"1000 sqft house prediction {w_final*1.0 + b_final:0.1f} Thousand dollars")
print(f"1200 sqft house prediction {w_final*1.2 + b_final:0.1f} Thousand dollars")
print(f"2000 sqft house prediction {w_final*2.0 + b_final:0.1f} Thousand dollars")
# Out:
# 1000 sqft house prediction 300.0 Thousand dollars
# 1200 sqft house prediction 340.0 Thousand dollars
# 2000 sqft house prediction 500.0 Thousand dollars

# %% [markdown]
# <a name="toc_40291_2.6"></a>
# ## Plotting
# You can show the progress of gradient descent during its execution by plotting the cost over iterations on a contour plot of the cost(w,b).

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 6))
plt_contour_wgrad(x_train, y_train, p_hist, ax)

# %% [markdown]
# Above, the contour plot shows the $cost(w,b)$ over a range of $w$ and $b$. Cost levels are represented by the rings. Overlayed, using red arrows, is the path of gradient descent. Here are some things to note:
# - The path makes steady (monotonic) progress toward its goal.
# - initial steps are much larger than the steps near the goal.

# %% [markdown]
# **Zooming in**, we can see that final steps of gradient descent. Note the distance between steps shrinks as the gradient approaches zero.

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 4))
plt_contour_wgrad(x_train, y_train, p_hist, ax, w_range=[180, 220, 0.5], b_range=[80, 120, 0.5],
            contours=[1,5,10,20],resolution=0.5)

# %% [markdown]
# <a name="toc_40291_2.7.1"></a>
# ### Increased Learning Rate
#
# <figure>
#  <img align="left", src="./images/C1_W1_Lab03_alpha_too_big.PNG"   style="width:340px;height:240px;" >
# </figure>
# In the lecture, there was a discussion related to the proper value of the learning rate, $\alpha$ in equation(3). The larger $\alpha$ is, the faster gradient descent will converge to a solution. But, if it is too large, gradient descent will diverge. Above you have an example of a solution which converges nicely.
#
# Let's try increasing the value of  $\alpha$ and see what happens:

# %%
# initialize parameters
w_init = 0
b_init = 0
# set alpha to a large value
iterations = 10
tmp_alpha = 8.0e-1
# run gradient descent
w_final, b_final, J_hist, p_hist = gradient_descent(x_train ,y_train, w_init, b_init, tmp_alpha, 
                                                    iterations, compute_cost, compute_gradient)
# Out:
# Iteration    0: Cost 2.58e+05  dj_dw: -6.500e+02, dj_db: -4.000e+02   w:  5.200e+02, b: 3.20000e+02
# Iteration    1: Cost 7.82e+05  dj_dw:  1.130e+03, dj_db:  7.000e+02   w: -3.840e+02, b:-2.40000e+02
# Iteration    2: Cost 2.37e+06  dj_dw: -1.970e+03, dj_db: -1.216e+03   w:  1.192e+03, b: 7.32800e+02
# Iteration    3: Cost 7.19e+06  dj_dw:  3.429e+03, dj_db:  2.121e+03   w: -1.551e+03, b:-9.63840e+02
# Iteration    4: Cost 2.18e+07  dj_dw: -5.974e+03, dj_db: -3.691e+03   w:  3.228e+03, b: 1.98886e+03
# Iteration    5: Cost 6.62e+07  dj_dw:  1.040e+04, dj_db:  6.431e+03   w: -5.095e+03, b:-3.15579e+03
# Iteration    6: Cost 2.01e+08  dj_dw: -1.812e+04, dj_db: -1.120e+04   w:  9.402e+03, b: 5.80237e+03
# Iteration    7: Cost 6.09e+08  dj_dw:  3.156e+04, dj_db:  1.950e+04   w: -1.584e+04, b:-9.80139e+03
# Iteration    8: Cost 1.85e+09  dj_dw: -5.496e+04, dj_db: -3.397e+04   w:  2.813e+04, b: 1.73730e+04
# ...

# %% [markdown]
# Above, $w$ and $b$ are bouncing back and forth between positive and negative with the absolute value increasing with each iteration. Further, each iteration $\frac{\partial J(w,b)}{\partial w}$ changes sign and cost is increasing rather than decreasing. This is a clear sign that the *learning rate is too large* and the solution is diverging.
# Let's visualize this with a plot.

# %%
plt_divergence(p_hist, J_hist,x_train, y_train)
plt.show()

# %% [markdown]
# Above, the left graph shows $w$'s progression over the first few steps of gradient descent. $w$ oscillates from positive to negative and cost grows rapidly. Gradient Descent is operating on both $w$ and $b$ simultaneously, so one needs the 3-D plot on the right for the complete picture.

# %% [markdown]
# ## Congratulations!
# In this lab you:
# - delved into the details of gradient descent for a single variable.
# - developed a routine to compute the gradient
# - visualized what the gradient is
# - completed a gradient descent routine
# - utilized gradient descent to find parameters
# - examined the impact of sizing the learning rate
